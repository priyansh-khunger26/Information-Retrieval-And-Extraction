# %% [markdown]
# These are the queries we made from the data set of Assignment 1

# %%
queries = [
    "What impact did the recent bombings in Baghdad have on local security measures?",
    "How has the Indonesian forest fire crisis affected neighboring countries like Singapore?",
    "What measures are in place to protect Shia pilgrims in Iraq following recent attacks?",
    "How did Alexander Van der Bellen's victory in the Austrian election impact European politics?",
    "What are the implications of the U.S. Supreme Court’s ruling in Salman v. U.S. for insider trading laws?",
    "What challenges remain after Colombia’s peace accord with FARC was signed?",
    "How are Egyptian authorities responding to the recent killing of a policeman in Cairo?",
    "What are the safety protocols in place at the New York City Metropolitan Opera after a recent disruption?",
    "What are the prospects for diplomatic relations between Iran and Canada following the release of Homa Hoodfar?",
    "What were the key issues in The Gambia’s recent elections?",
    "How is Singapore addressing the health and environmental impacts of Indonesian fires?",
    "What security precautions are being taken for future religious gatherings in Iraq after recent attacks?",
    "How does the Austrian election reflect broader political trends in Europe?",
    "What steps are being taken to prevent further incidents like the Metropolitan Opera disruption?",
    "What does the peace accord with FARC mean for Colombia’s future political landscape?"
]

# %% [markdown]
# Now, loading the documents and further training a WORD2VEC model on this data set.

# %%
import os
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess

def load_documents(folder_path):
    """
    Load and preprocess text files in a given folder.
    
    Args:
        folder_path (str): Path to the folder containing .txt documents.
    
    Returns:
        list of list of str: List of tokenized documents, each document is represented as a list of words.
    """
    documents = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
                tokenized_content = simple_preprocess(content)  # Tokenize and preprocess
                documents.append(tokenized_content)
    return documents

# %%
def train_word2vec(documents, vector_size=100, window=5, min_count=1, workers=4):
    """
    Train a Word2Vec model on the given documents.
    
    Args:
        documents (list of list of str): Tokenized documents for training.
        vector_size (int): Dimensionality of word vectors.
        window (int): Maximum distance between the current and predicted word.
        min_count (int): Ignores words with total frequency lower than this.
        workers (int): Number of worker threads to train the model.
    
    Returns:
        Word2Vec: Trained Word2Vec model.
    """
    model = Word2Vec(sentences=documents, vector_size=vector_size, window=window, min_count=min_count, workers=workers)
    return model

# %%
folder_path = "/kaggle/input/data-set/documents"  # Replace with your folder path

# Step 1: Load and preprocess documents
documents = load_documents(folder_path)

# %%
documents[1]
# Out:
# ['this',
#  'article',
#  'is',
#  'more',
#  'than',
#  'months',
#  'old',
#  'this',
#  'article',
#  'is',
#  'more',
#  'than',
#  'months',
#  'old',
#  'tourist',
#  'attractions',
#  'and',
#  'museums',
#  'in',
#  'central',
#  'paris',
#  'have',
#  'said',
#  'they',
#  'will',
#  'not',
#  'open',
#  'on',
#  'saturday',
#  'when',
#  'fresh',
#  'gilets',
#  'jaunes',
#  'yellow',
#  'vests',
#  'protests',
#  'are',
#  'planned',
#  'as',
#  'french',
#  'authorities',
#  'prepared',
#  'to',
#  'deploy',
#  'security',
#  'personnel',
#  'across',
#  'the',
#  'country',
#  'the',
#  'demonstrations',
#  'announced',
#  'on',
#  'saturday',
#  'december',
#  'in',
#  'paris',
#  'do',
#  'not',
#  'allow',
#  'us',
#  'to',
#  'welcome',
#  'visitors',
#  'in',
#  'safe',
#  'conditions',
#  'said',
#  'the',
#  'operator',
#  'of',
#  'the',
#  'eiffel',
#  'tower',
#  'in',
#  'statement',
#  'on',
#  'thursday',
#  'police',
#  'have',
#  'also',
#  'ordered',
#  'about',
#  'dozen',
#  'museums',
#  'including',
#  'the',
#  'louvre',
#  'and',
#  'the',
#  'grand',
#  'palais',
#  'cultural',
#  'sites',
#  'such',
#  'as',
#  'the',
#  'opera',
#  'and',
#  'shops',
#  'along',
#  'the',
#  'champs',
#  'élysées',
#  'to',
#  'close',
#  'over',
#  'fears',
#  'of',
#  'violence',
#  'we',
#  'cannot',
#  'take',
#  'the',
#  'risk',
#  'when',
#  'we',
#  'know',
#  'the',
#  'threat',
#  'franck',
#  'riester',
#  'the',
#  'culture',
#  'minister',
#  'told',
#  'rtl',
#  'radio',
#  'several',
#  'top',
#  'league',
#  'football',
#  'matches',
#  'have',
#  'also',
#  'been',
#  'cancelled',
#  'as',
#  'senior',
#  'ministers',
#  'sought',
#  'to',
#  'defuse',
#  'public',
#  'fury',
#  'with',
#  'conciliatory',
#  'language',
#  'on',
#  'taxes',
#  'an',
#  'official',
#  'in',
#  'emmanuel',
#  'macron',
#  'office',
#  'risked',
#  'provoking',
#  'more',
#  'anger',
#  'by',
#  'saying',
#  'that',
#  'intelligence',
#  'suggested',
#  'that',
#  'some',
#  'protesters',
#  'would',
#  'come',
#  'to',
#  'the',
#  'capital',
#  'to',
#  'vandalise',
#  'and',
#  'to',
#  'kill',
#  'play',
#  'video',
#  'french',
#  'high',
#  'school',
#  'students',
#  'made',
#  'to',
#  'kneel',
#  'with',
#  'hands',
#  'on',
#  'heads',
#  'by',
#  'police',
#  'video',
#  'despite',
#  'capitulating',
#  'this',
#  'week',
#  'over',
#  'the',
#  'plans',
#  'for',
#  'higher',
#  'fuel',
#  'taxes',
#  'that',
#  'inspired',
#  'the',
#  'nationwide',
#  'revolt',
#  'the',
#  'president',
#  'has',
#  'struggled',
#  'to',
#  'quell',
#  'the',
#  'anger',
#  'that',
#  'last',
#  'weekend',
#  'led',
#  'to',
#  'the',
#  'worst',
#  'street',
#  'unrest',
#  'in',
#  'central',
#  'paris',
#  'since',
#  'rioters',
#  'torched',
#  'cars',
#  'vandalised',
#  'cafes',
#  'looted',
#  'shops',
#  'and',
#  'sprayed',
#  'anti',
#  'macron',
#  'graffiti',
#  'across',
#  'some',
#  'of',
#  'paris',
#  'most',
#  'affluent',
#  'districts',
#  'even',
#  'defacing',
#  'the',
#  'arc',
#  'de',
#  'triomphe',
#  'scores',
#  'of',
#  'people',
#  'were',
#  'hurt',
#  'and',
#  'hundreds',
#  'arrested',
#  'in',
#  'battles',
#  'with',
#  'police',
#  'macron',
#  'politics',
#  'look',
#  'to',
#  'blair',
#  'and',
#  'clinton',
#  'the',
#  'backlash',
#  'was',
#  'inevitable',
#  'larry',
#  'elliott',
#  'read',
#  'more',
#  'in',
#  'bid',
#  'to',
#  'end',
#  'the',
#  'three',
#  'week',
#  'crisis',
#  'the',
#  'prime',
#  'minister',
#  'édouard',
#  'philippe',
#  'told',
#  'parliament',
#  'late',
#  'on',
#  'wednesday',
#  'that',
#  'he',
#  'was',
#  'scrapping',
#  'the',
#  'fuel',
#  'tax',
#  'increases',
#  'planned',
#  'for',
#  'having',
#  'announced',
#  'six',
#  'month',
#  'suspension',
#  'the',
#  'day',
#  'before',
#  'the',
#  'finance',
#  'minister',
#  'bruno',
#  'le',
#  'maire',
#  'told',
#  'conference',
#  'he',
#  'was',
#  'prepared',
#  'to',
#  'bring',
#  'forward',
#  'tax',
#  'cutting',
#  'plans',
#  'and',
#  'that',
#  'he',
#  'wanted',
#  'workers',
#  'bonuses',
#  'to',
#  'be',
#  'tax',
#  'free',
#  'but',
#  'he',
#  'added',
#  'in',
#  'this',
#  'case',
#  'it',
#  'must',
#  'go',
#  'hand',
#  'in',
#  'hand',
#  'with',
#  'decrease',
#  'in',
#  'spending',
#  'he',
#  'also',
#  'said',
#  'france',
#  'would',
#  'impose',
#  'tax',
#  'on',
#  'big',
#  'internet',
#  'firms',
#  'in',
#  'if',
#  'there',
#  'was',
#  'no',
#  'consensus',
#  'on',
#  'an',
#  'eu',
#  'wide',
#  'levy',
#  'seeking',
#  'to',
#  'appeal',
#  'to',
#  'anti',
#  'business',
#  'sentiment',
#  'among',
#  'the',
#  'protesters',
#  'the',
#  'threat',
#  'of',
#  'more',
#  'violence',
#  'poses',
#  'security',
#  'nightmare',
#  'for',
#  'the',
#  'authorities',
#  'who',
#  'make',
#  'distinction',
#  'between',
#  'the',
#  'peaceful',
#  'gilets',
#  'jaunes',
#  'protesters',
#  'and',
#  'violent',
#  'groups',
#  'anarchists',
#  'and',
#  'looters',
#  'from',
#  'the',
#  'deprived',
#  'suburbs',
#  'who',
#  'they',
#  'say',
#  'have',
#  'infiltrated',
#  'the',
#  'movement',
#  'on',
#  'facebook',
#  'groups',
#  'and',
#  'across',
#  'social',
#  'media',
#  'the',
#  'gilets',
#  'jaunes',
#  'are',
#  'calling',
#  'for',
#  'an',
#  'act',
#  'reference',
#  'to',
#  'what',
#  'would',
#  'be',
#  'fourth',
#  'weekend',
#  'of',
#  'disorder',
#  'france',
#  'is',
#  'fed',
#  'up',
#  'we',
#  'will',
#  'be',
#  'there',
#  'in',
#  'bigger',
#  'numbers',
#  'stronger',
#  'standing',
#  'up',
#  'for',
#  'french',
#  'people',
#  'meet',
#  'in',
#  'paris',
#  'on',
#  'dec',
#  'said',
#  'one',
#  'group',
#  'banner',
#  'the',
#  'education',
#  'minister',
#  'jean',
#  'michel',
#  'blanquer',
#  'urged',
#  'people',
#  'to',
#  'stay',
#  'at',
#  'home',
#  'this',
#  'weekend',
#  'security',
#  'sources',
#  'said',
#  'the',
#  'government',
#  'was',
#  'considering',
#  'using',
#  'troops',
#  'currently',
#  'deployed',
#  'on',
#  'anti',
#  'terrorism',
#  'patrols',
#  'to',
#  'protect',
#  'public',
#  'buildings',
#  'the',
#  'protests',
#  'named',
#  'after',
#  'the',
#  'fluorescent',
#  'jackets',
#  'french',
#  'motorists',
#  'are',
#  'required',
#  'to',
#  'keep',
#  'in',
#  'their',
#  'cars',
#  'erupted',
#  'in',
#  'november',
#  'over',
#  'the',
#  'squeeze',
#  'on',
#  'household',
#  'budgets',
#  'caused',
#  'by',
#  'fuel',
#  'taxes',
#  'demonstrations',
#  'swiftly',
#  'grew',
#  'into',
#  'broad',
#  'sometimes',
#  'violent',
#  'rebellion',
#  'against',
#  'macron',
#  'who',
#  'are',
#  'the',
#  'gilets',
#  'jaunes',
#  'and',
#  'what',
#  'do',
#  'they',
#  'want',
#  'read',
#  'more',
#  'the',
#  'protesters',
#  'have',
#  'no',
#  'formal',
#  'leader',
#  'and',
#  'their',
#  'demands',
#  'are',
#  'diverse',
#  'they',
#  'include',
#  'changes',
#  'to',
#  'tax',
#  'system',
#  'perceived',
#  'as',
#  'unfair',
#  'and',
#  'unjust',
#  'higher',
#  'salaries',
#  'and',
#  'macron',
#  'resignation',
#  'france',
#  'hard',
#  'left',
#  'cgt',
#  'trade',
#  'union',
#  'on',
#  'thursday',
#  'called',
#  'on',
#  'its',
#  'energy',
#  'industry',
#  'workers',
#  'to',
#  'walk',
#  'out',
#  'for',
#  'hours',
#  'from',
#  'december',
#  'saying',
#  'it',
#  'wanted',
#  'to',
#  'join',
#  'forces',
#  'with',
#  'the',
#  'gilets',
#  'jaunes',
#  'the',
#  'fuel',
#  'tax',
#  'volte',
#  'face',
#  'was',
#  'the',
#  'first',
#  'major',
#  'turn',
#  'of',
#  'macron',
#  'month',
#  'presidency',
#  'the',
#  'unrest',
#  'has',
#  'exposed',
#  'deep',
#  'seated',
#  'resentment',
#  'among',
#  'non',
#  'city',
#  'dwellers',
#  'with',
#  'perception',
#  'that',
#  'macron',
#  'is',
#  'out',
#  'of',
#  'touch',
#  'with',
#  'the',
#  'middle',
#  'and',
#  'working',
#  'classes',
#  'they',
#  'see',
#  'the',
#  'year',
#  'old',
#  'former',
#  'investment',
#  'banker',
#  'as',
#  'closer',
#  'to',
#  'big',
#  'business',
#  'and',
#  'the',
#  'rich',
#  'trouble',
#  'is',
#  'also',
#  'brewing',
#  'elsewhere',
#  'for',
#  'macron',
#  'teenage',
#  'students',
#  'blocked',
#  'access',
#  'to',
#  'more',
#  'than',
#  'high',
#  'schools',
#  'across',
#  'the',
#  'country',
#  'on',
#  'thursday',
#  'burning',
#  'garbage',
#  'bins',
#  'and',
#  'setting',
#  'car',
#  'alight',
#  'in',
#  'the',
#  'western',
#  'city',
#  'of',
#  'nantes',
#  'farmers',
#  'who',
#  'have',
#  'long',
#  'complained',
#  'that',
#  'retailers',
#  'are',
#  'squeezing',
#  'their',
#  'margins',
#  'and',
#  'are',
#  'furious',
#  'over',
#  'delay',
#  'to',
#  'the',
#  'planned',
#  'rise',
#  'in',
#  'minimum',
#  'food',
#  'prices',
#  'and',
#  'truckers',
#  'are',
#  'threatening',
#  'to',
#  'strike',
#  'from',
#  'sunday',
#  'le',
#  'maire',
#  'said',
#  'france',
#  'was',
#  'no',
#  'longer',
#  'spared',
#  'from',
#  'the',
#  'wave',
#  'of',
#  'populism',
#  'that',
#  'had',
#  'swept',
#  'across',
#  'europe',
#  'it',
#  'only',
#  'that',
#  'in',
#  'france',
#  'it',
#  'not',
#  'manifesting',
#  'itself',
#  'at',
#  'the',
#  'ballot',
#  'box',
#  'but',
#  'in',
#  'the',
#  'streets',
#  'france',
#  'is',
#  'bracing',
#  'for',
#  'yet',
#  'another',
#  'weekend',
#  'of',
#  'protests',
#  'that',
#  'could',
#  'rock',
#  'paris',
#  'and',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'country',
#  'prime',
#  'minister',
#  'edouard',
#  'philippe',
#  'said',
#  'the',
#  'government',
#  'was',
#  'deploying',
#  'security',
#  'force',
#  'members',
#  'across',
#  'france',
#  'including',
#  'in',
#  'the',
#  'capital',
#  'in',
#  'case',
#  'the',
#  'demonstrations',
#  'turn',
#  'violent',
#  'again',
#  'many',
#  'of',
#  'the',
#  'capital',
#  'famed',
#  'sites',
#  'including',
#  'the',
#  'louvre',
#  'the',
#  'eiffel',
#  'tower',
#  'the',
#  'musée',
#  'delacroix',
#  'and',
#  'the',
#  'paris',
#  'opera',
#  'will',
#  'close',
#  'over',
#  'the',
#  'weekend',
#  'in',
#  'advance',
#  'of',
#  'the',
#  'protests',
#  'organized',
#  'by',
#  'the',
#  'gilets',
#  'jaunes',
#  'or',
#  'yellow',
#  'vest',
#  'movement',
#  'their',
#  'name',
#  'comes',
#  'from',
#  'the',
#  'high',
#  'visibility',
#  'yellow',
#  'vests',
#  'that',
#  'drivers',
#  'are',
#  'required',
#  'to',
#  'keep',
#  'in',
#  'their',
#  'vehicles',
#  'for',
#  'safety',
#  'reasons',
#  'interior',
#  'minister',
#  'christophe',
#  'castaner',
#  'vowed',
#  'to',
#  'deploy',
#  'all',
#  'the',
#  'means',
#  'available',
#  'to',
#  'ensure',
#  'the',
#  'latest',
#  'yellow',
#  'vest',
#  'protests',
#  'are',
#  'not',
#  'hijacked',
#  'by',
#  'what',
#  'he',
#  'said',
#  'were',
#  'people',
#  'small',
#  'minority',
#  'of',
#  'the',
#  'movement',
#  'who',
#  'have',
#  'been',
#  'radicalized',
#  'and',
#  'fallen',
#  'into',
#  'violence',
#  'and',
#  'hate',
#  'we',
#  'have',
#  'to',
#  'guarantee',
#  'the',
#  'safety',
#  'of',
#  'protesters',
#  'and',
#  'the',
#  'right',
#  'of',
#  'citizens',
#  'to',
#  'move',
#  'around',
#  'freely',
#  'castaner',
#  'told',
#  'news',
#  'conference',
#  'friday',
#  'stores',
#  'along',
#  'the',
#  'capital',
#  'famed',
#  'champs',
#  'elysees',
#  'avenue',
#  'have',
#  'also',
#  'been',
#  'advised',
#  'to',
#  'remain',
#  'shut',
#  'this',
#  'weekend',
#  'many',
#  'shop',
#  'owners',
#  'were',
#  'boarding',
#  'up',
#  'their',
#  'stores',
#  'on',
#  'friday',
#  'amid',
#  'fears',
#  'of',
#  'further',
#  'disorder',
#  'the',
#  'french',
#  'retail',
#  'sector',
#  'has',
#  'suffered',
#  'loss',
#  'in',
#  'revenue',
#  'of',
#  'about',
#  'billion',
#  'since',
#  'the',
#  'beginning',
#  'of',
#  'the',
#  'yellow',
#  'vest',
#  'protests',
#  'last',
#  'month',
#  ...]

# %%
# Step 2: Train Word2Vec model
word2vec_model = train_word2vec(documents)

# %% [markdown]
# <h2>TRAINED WORD2VEC MODEL</h2>

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def mean_pool_embedding(text, model):
    """
    Compute the mean-pooling of word embeddings for a given text.
    
    Args:
        text (str): Input text to vectorize.
        model (Word2Vec): Trained Word2Vec model.
    
    Returns:
        numpy.ndarray: Mean-pooled vector for the input text.
    """
    # Check if text is a list or string
    if isinstance(text, list):
        text = ' '.join(text)  # Convert list of words to a single string if needed
    
    if not isinstance(text, str):
        raise TypeError("Expected text to be a string, got {type(text)} instead.")
    
    words = simple_preprocess(text)  # Tokenize and preprocess the string
    word_vectors = [model.wv[word] for word in words if word in model.wv]
    
    if not word_vectors:
        return np.zeros(model.vector_size)  # Return a zero vector if no words are in the model
    return np.mean(word_vectors, axis=0)

def vectorize_documents(documents, model):
    """
    Vectorize a list of documents using mean-pooling.
    
    Args:
        documents (list of str): List of document contents as strings.
        model (Word2Vec): Trained Word2Vec model.
    
    Returns:
        list of numpy.ndarray: List of mean-pooled document vectors.
    """
    return [mean_pool_embedding(doc, model) for doc in documents]

def vectorize_queries(queries, model):
    """
    Vectorize a list of queries using mean-pooling.
    
    Args:
        queries (list of str): List of query strings.
        model (Word2Vec): Trained Word2Vec model.
    
    Returns:
        list of numpy.ndarray: List of mean-pooled query vectors.
    """
    return [mean_pool_embedding(query, model) for query in queries]

def rank_documents(queries, query_vectors, document_vectors, k=5):
    """
    Rank documents for each query based on cosine similarity.
    
    Args:
        queries (list of str): List of query strings.
        query_vectors (list of numpy.ndarray): List of query vectors.
        document_vectors (list of numpy.ndarray): List of document vectors.
        k (int): Number of top documents to retrieve.
    
    Returns:
        dict: A dictionary with queries as keys and lists of top-k document indices as values.
    """
    rankings = {}
    for query, query_vector in zip(queries, query_vectors):
        similarities = cosine_similarity([query_vector], document_vectors)[0]
        ranked_indices = np.argsort(similarities)[::-1][:k]
        rankings[query] = ranked_indices
    return rankings

# %%
# Vectorize documents and queries
document_vectors = vectorize_documents(documents, word2vec_model)
query_vectors = vectorize_queries(queries, word2vec_model)

# Rank top-k documents for each query
k = 5  # Number of top documents to retrieve for each query
rankings = rank_documents(queries, query_vectors, document_vectors, k)

# Display rankings
for query, indices in rankings.items():
    print(f"Query: '{query}'")
    print("Top documents:")
    for idx in indices:
        print(f" - Document {idx}: {documents[idx][:100]}...")
# Out:
# Query: 'What impact did the recent bombings in Baghdad have on local security measures?'
# Top documents:
#  - Document 6500: ['mazar', 'sharif', 'afghanistan', 'at', 'least', 'members', 'of', 'security', 'forces', 'in', 'northern', 'afghanistan', 'were', 'killed', 'by', 'the', 'taliban', 'in', 'series', 'of', 'coordinated', 'attacks', 'on', 'tuesday', 'officials', 'said', 'and', 'dozens', 'of', 'others', 'were', 'wounded', 'the', 'deadliest', 'violence', 'took', 'place', 'in', 'sar', 'pul', 'province', 'where', 'the', 'taliban', 'attacked', 'afghan', 'security', 'forces', 'in', 'three', 'areas', 'killing', 'total', 'of', 'people', 'officials', 'said', 'the', 'officials', 'did', 'not', 'provide', 'breakdown', 'of', 'casualties', 'zabihullah', 'amani', 'the', 'spokesman', 'for', 'the', 'governor', 'of', 'sar', 'pul', 'said', 'the', 'taliban', 'had', 'simultaneously', 'attacked', 'the', 'center', 'of', 'sayad', 'district', 'security', 'outposts', 'along', 'the', 'highway', 'linking', 'sar', 'pul', 'with', 'jowzjan', 'and', 'village', 'with', 'oil']...
#  - Document 1575: ['german', 'chancellor', 'angela', 'merkel', 'has', 'said', 'deportations', 'of', 'failed', 'asylum', 'seekers', 'to', 'afghanistan', 'would', 'continue', 'despite', 'this', 'week', 'massive', 'truck', 'bombing', 'in', 'kabul', 'merkel', 'made', 'the', 'comments', 'on', 'june', 'day', 'after', 'bomb', 'blast', 'killed', 'at', 'least', 'people', 'and', 'wounded', 'more', 'than', 'in', 'kabul', 'diplomatic', 'quarter', 'following', 'the', 'attack', 'germany', 'canceled', 'plane', 'that', 'was', 'to', 'take', 'deportees', 'to', 'kabul', 'the', 'chancellor', 'said', 'berlin', 'will', 'continue', 'to', 'closely', 'evaluate', 'the', 'security', 'situation', 'in', 'afghanistan', 'before', 'deporting', 'rejected', 'asylum', 'seekers', 'back', 'there', 'the', 'kabul', 'attack', 'represents', 'chance', 'to', 'once', 'again', 'look', 'carefully', 'and', 'to', 'analyze', 'the', 'security', 'situation', 'province', 'by', 'province', 'merkel', 'said']...
#  - Document 6589: ['image', 'copyright', 'afp', 'image', 'caption', 'some', 'victims', 'were', 'buried', 'hours', 'later', 'in', 'the', 'shia', 'muslim', 'holy', 'city', 'of', 'najaf', 'two', 'suicide', 'bombers', 'have', 'killed', 'at', 'least', 'people', 'and', 'injured', 'in', 'an', 'attack', 'on', 'baghdad', 'square', 'where', 'day', 'labourers', 'gather', 'to', 'look', 'for', 'work', 'they', 'set', 'off', 'their', 'devices', 'at', 'intervals', 'sending', 'people', 'scattering', 'across', 'tayaran', 'square', 'in', 'the', 'centre', 'of', 'the', 'iraqi', 'capital', 'scores', 'of', 'labourers', 'are', 'said', 'to', 'be', 'among', 'the', 'dead', 'and', 'injured', 'attacks', 'on', 'the', 'city', 'had', 'become', 'less', 'frequent', 'since', 'the', 'islamic', 'state', 'group', 'lost', 'its', 'iraqi', 'strongholds', 'last', 'year', 'the', 'government', 'declared', 'it', 'had', 'retaken']...
#  - Document 2215: ['dubai', 'reuters', 'hackers', 'have', 'attacked', 'networks', 'in', 'number', 'of', 'countries', 'including', 'data', 'centers', 'in', 'iran', 'where', 'they', 'left', 'the', 'image', 'of', 'flag', 'on', 'screens', 'along', 'with', 'warning', 'don', 'mess', 'with', 'our', 'elections', 'the', 'iranian', 'it', 'ministry', 'said', 'on', 'saturday', 'file', 'photo', 'man', 'types', 'on', 'computer', 'keyboard', 'in', 'front', 'of', 'the', 'displayed', 'cyber', 'code', 'in', 'this', 'illustration', 'picture', 'taken', 'on', 'march', 'reuters', 'kacper', 'pempel', 'illustration', 'file', 'photo', 'the', 'attack', 'apparently', 'affected', 'router', 'switches', 'across', 'the', 'world', 'in', 'widespread', 'attack', 'including', 'switches', 'in', 'our', 'country', 'the', 'communication', 'and', 'information', 'technology', 'ministry', 'said', 'in', 'statement', 'carried', 'by', 'iran', 'official', 'news', 'agency', 'irna', 'the']...
#  - Document 1085: ['islamabad', 'taliban', 'militants', 'have', 'seized', 'control', 'of', 'an', 'army', 'base', 'in', 'northern', 'afghanistan', 'killing', 'and', 'capturing', 'dozens', 'of', 'government', 'soldiers', 'the', 'fall', 'of', 'camp', 'chenaya', 'in', 'the', 'ghormach', 'district', 'of', 'faryab', 'province', 'late', 'monday', 'followed', 'two', 'days', 'of', 'intense', 'fighting', 'officials', 'say', 'the', 'afghan', 'national', 'army', 'ana', 'base', 'was', 'lost', 'after', 'soldiers', 'failed', 'to', 'receive', 'reinforcements', 'and', 'air', 'support', 'and', 'ran', 'out', 'of', 'ammunition', 'and', 'other', 'supplies', 'ghormach', 'district', 'afghanistan', 'regional', 'military', 'and', 'government', 'officials', 'tuesday', 'confirmed', 'to', 'voa', 'that', 'of', 'the', 'soldiers', 'stationed', 'at', 'the', 'base', 'surrendered', 'to', 'the', 'taliban', 'they', 'said', 'the', 'rest', 'have', 'either', 'been', 'killed', 'or']...
# Query: 'How has the Indonesian forest fire crisis affected neighboring countries like Singapore?'
# Top documents:
#  - Document 2224: ['image', 'copyright', 'afp', 'image', 'caption', 'about', 'million', 'people', 'in', 'india', 'have', 'been', 'hit', 'by', 'flooding', 'more', 'than', 'million', 'people', 'have', 'now', 'been', 'affected', 'by', 'seasonal', 'flooding', 'across', 'swathe', 'of', 'south', 'asia', 'say', 'aid', 'officials', 'the', 'floods', 'in', 'nepal', 'bangladesh', 'and', 'india', 'are', 'thought', 'to', 'have', 'killed', 'about', 'people', 'and', 'are', 'expected', 'to', 'worsen', 'the', 'international', 'federation', 'of', 'red', 'cross', 'and', 'red', 'crescent', 'societies', 'ifrc', 'says', 'it', 'is', 'becoming', 'one', 'of', 'the', 'worst', 'regional', 'humanitarian', 'crises', 'in', 'years', 'there', 'are', 'growing', 'concerns', 'about', 'food', 'shortages', 'and', 'disease', 'image', 'copyright', 'epa', 'image', 'caption', 'these', 'woman', 'were', 'seeking', 'shelter', 'and', 'aid', 'after', 'fleeing']...
#  - Document 3520: ['image', 'copyright', 'afp', 'image', 'caption', 'residents', 'paddle', 'through', 'lokoja', 'town', 'in', 'kogi', 'state', 'more', 'than', 'people', 'have', 'died', 'in', 'floods', 'after', 'nigeria', 'two', 'major', 'rivers', 'burst', 'their', 'banks', 'authorities', 'say', 'the', 'national', 'emergency', 'management', 'agency', 'nema', 'says', 'heavy', 'rains', 'caused', 'the', 'niger', 'river', 'and', 'benue', 'river', 'to', 'overflow', 'it', 'has', 'resulted', 'in', 'series', 'of', 'floods', 'across', 'the', 'country', 'over', 'two', 'weeks', 'with', 'rural', 'areas', 'most', 'vulnerable', 'the', 'government', 'is', 'urging', 'residents', 'along', 'waterways', 'to', 'relocate', 'to', 'safe', 'places', 'thousands', 'of', 'people', 'have', 'been', 'displaced', 'and', 'vast', 'swathes', 'of', 'farmlands', 'have', 'been', 'destroyed', 'by', 'the', 'floods', 'in', 'central', 'and', 'southern', 'nigeria']...
#  - Document 5656: ['image', 'copyright', 'getty', 'images', 'image', 'caption', 'lokoja', 'where', 'the', 'niger', 'and', 'benue', 'rivers', 'meet', 'heavy', 'seasonal', 'rains', 'are', 'regular', 'feature', 'of', 'life', 'in', 'nigeria', 'and', 'towns', 'close', 'to', 'the', 'country', 'main', 'rivers', 'are', 'particularly', 'vulnerable', 'this', 'year', 'floods', 'have', 'killed', 'almost', 'people', 'with', 'many', 'thousands', 'displaced', 'the', 'national', 'emergency', 'management', 'agency', 'nema', 'say', 'these', 'figures', 'are', 'likely', 'to', 'rise', 'as', 'the', 'full', 'impact', 'becomes', 'clear', 'state', 'of', 'emergency', 'has', 'been', 'declared', 'in', 'four', 'of', 'the', 'worst', 'hit', 'states', 'niger', 'kogi', 'anambra', 'delta', 'president', 'muhammadu', 'buhari', 'has', 'pledged', 'for', 'relief', 'efforts', 'the', 'nema', 'has', 'activated', 'five', 'local', 'operation', 'centres', 'to', 'coordinate']...
#  - Document 5948: ['geneva', 'reuters', 'severe', 'flooding', 'in', 'north', 'korea', 'has', 'killed', 'at', 'least', 'people', 'with', 'nearly', 'the', 'same', 'number', 'missing', 'and', 'thousands', 'left', 'homeless', 'by', 'the', 'destruction', 'the', 'international', 'federation', 'of', 'red', 'cross', 'and', 'red', 'crescent', 'societies', 'said', 'on', 'thursday', 'volunteers', 'from', 'the', 'national', 'red', 'cross', 'are', 'conducting', 'search', 'and', 'rescue', 'operations', 'in', 'north', 'and', 'south', 'hwanghae', 'provinces', 'where', 'heavy', 'rains', 'began', 'on', 'august', 'it', 'said', 'adding', 'that', 'many', 'children', 'were', 'among', 'the', 'missing', 'heavy', 'rains', 'in', 'recent', 'days', 'triggered', 'large', 'scale', 'flooding', 'and', 'landslides', 'in', 'low', 'lying', 'areas', 'destroying', 'more', 'than', 'buildings', 'including', 'homes', 'clinics', 'and', 'schools', 'the', 'geneva', 'based', 'federation']...
#  - Document 5734: ['media', 'playback', 'is', 'unsupported', 'on', 'your', 'device', 'media', 'caption', 'residents', 'and', 'emergency', 'crews', 'battle', 'against', 'the', 'fires', 'in', 'the', 'bio', 'bio', 'region', 'more', 'international', 'help', 'has', 'been', 'arriving', 'in', 'chile', 'to', 'help', 'the', 'country', 'fight', 'the', 'worst', 'wildfire', 'in', 'its', 'modern', 'history', 'russia', 'has', 'sent', 'super', 'tanker', 'aircraft', 'capable', 'of', 'carrying', 'tons', 'of', 'water', 'to', 'douse', 'the', 'fires', 'the', 'series', 'of', 'fast', 'spreading', 'fires', 'mostly', 'in', 'chile', 'central', 'region', 'are', 'being', 'fanned', 'by', 'strong', 'winds', 'high', 'temperatures', 'and', 'prolonged', 'drought', 'one', 'town', 'santa', 'olga', 'has', 'been', 'destroyed', 'by', 'the', 'blaze', 'image', 'copyright', 'afp', 'image', 'caption', 'in', 'santa', 'olga', 'homes', 'in']...
# Query: 'What measures are in place to protect Shia pilgrims in Iraq following recent attacks?'
# Top documents:
#  - Document 945: ['egypt', 'declares', 'three', 'month', 'state', 'of', 'emergency', 'after', 'palm', 'sunday', 'church', 'bombings', 'kill', 'updated', 'egyptian', 'president', 'abdel', 'fattah', 'al', 'sisi', 'has', 'declared', 'three', 'month', 'state', 'of', 'emergency', 'after', 'suicide', 'bombers', 'targeted', 'two', 'coptic', 'churches', 'killing', 'at', 'least', 'people', 'and', 'injuring', 'dozens', 'more', 'in', 'the', 'run', 'up', 'to', 'easter', 'key', 'points', 'under', 'emergency', 'law', 'constitutional', 'rights', 'are', 'suspended', 'police', 'are', 'given', 'more', 'power', 'the', 'islamic', 'state', 'group', 'has', 'claimed', 'responsibility', 'for', 'the', 'deadly', 'attacks', 'attacks', 'on', 'coptic', 'churches', 'in', 'muslim', 'majority', 'egypt', 'occur', 'regularly', 'at', 'least', 'people', 'were', 'killed', 'and', 'injured', 'in', 'the', 'first', 'blast', 'at', 'coptic', 'church', 'in', 'the', 'nile']...
#  - Document 1623: ['egyptian', 'forces', 'have', 'struck', 'terrorist', 'training', 'camps', 'in', 'retaliation', 'for', 'an', 'attack', 'on', 'coptic', 'christians', 'president', 'abdul', 'fattah', 'al', 'sisi', 'has', 'said', 'state', 'media', 'say', 'six', 'strikes', 'hit', 'the', 'town', 'of', 'derna', 'in', 'neighbouring', 'libya', 'gunmen', 'earlier', 'attacked', 'bus', 'carrying', 'worshippers', 'in', 'central', 'egypt', 'killing', 'at', 'least', 'people', 'and', 'wounding', 'others', 'president', 'sisi', 'said', 'he', 'would', 'not', 'hesitate', 'to', 'strike', 'terrorist', 'camps', 'anywhere', 'announcing', 'the', 'strike', 'in', 'tv', 'speech', 'late', 'on', 'friday', 'he', 'promised', 'to', 'protect', 'our', 'people', 'from', 'the', 'evil', 'countries', 'supporting', 'terrorism', 'should', 'be', 'punished', 'he', 'said', 'as', 'he', 'appealed', 'to', 'us', 'president', 'donald', 'trump', 'for', 'help', 'military']...
#  - Document 3392: ['mosul', 'iraq', 'the', 'latest', 'on', 'the', 'iraqi', 'offensive', 'to', 'retake', 'mosul', 'all', 'times', 'local', 'iraqi', 'forces', 'trying', 'to', 'advance', 'further', 'into', 'mosul', 'are', 'battling', 'waves', 'of', 'car', 'bombs', 'sent', 'by', 'the', 'islamic', 'state', 'group', 'iraqi', 'special', 'forces', 'maj', 'gen', 'sami', 'al', 'aridi', 'said', 'sunday', 'that', 'there', 'are', 'so', 'many', 'civilian', 'cars', 'and', 'any', 'one', 'of', 'them', 'could', 'be', 'bomb', 'iraqi', 'forces', 'say', 'they', 'have', 'cleared', 'the', 'of', 'qadisiya', 'and', 'zahra', 'and', 'are', 'now', 'planning', 'to', 'move', 'deeper', 'into', 'the', 'city', 'they', 'are', 'building', 'sand', 'berms', 'and', 'road', 'blocks', 'to', 'prevent', 'car', 'bombs', 'from', 'breaching', 'the', 'front', 'lines', 'iraqi', 'forces', 'pushed']...
#  - Document 4054: ['hundreds', 'of', 'muslim', 'clergymen', 'in', 'pakistan', 'have', 'issued', 'joint', 'religious', 'directive', 'that', 'forbids', 'muslims', 'from', 'carrying', 'out', 'suicide', 'bombing', 'attacks', 'over', 'pakistani', 'muslim', 'clerics', 'have', 'issued', 'fatwa', 'aimed', 'at', 'prohibiting', 'the', 'use', 'of', 'probably', 'one', 'of', 'the', 'most', 'gruesome', 'and', 'indiscriminate', 'methods', 'employed', 'by', 'terrorists', 'across', 'the', 'world', 'suicide', 'bombing', 'according', 'to', 'book', 'soon', 'to', 'be', 'revealed', 'by', 'the', 'country', 'government', 'and', 'cited', 'by', 'media', 'the', 'fatwa', 'declares', 'suicide', 'bombings', 'haram', 'forbidden', 'to', 'muslim', 'faithful', 'we', 'can', 'seek', 'guidance', 'from', 'this', 'fatwa', 'for', 'building', 'national', 'narrative', 'in', 'order', 'to', 'curb', 'extremism', 'in', 'keeping', 'with', 'the', 'golden', 'principles', 'of', 'islam', 'pakistani']...
#  - Document 6397: ['protests', 'that', 'began', 'last', 'week', 'in', 'iraq', 'are', 'continuing', 'amid', 'widespread', 'anger', 'over', 'abysmal', 'public', 'services', 'provision', 'by', 'the', 'government', 'the', 'unrest', 'threatens', 'to', 'delay', 'formation', 'of', 'new', 'government', 'mandated', 'after', 'iraq', 'elections', 'in', 'may', 'and', 'has', 'already', 'led', 'to', 'break', 'ins', 'to', 'oil', 'facilities', 'and', 'political', 'offices', 'first', 'sparked', 'in', 'the', 'oil', 'rich', 'southern', 'province', 'of', 'basra', 'and', 'spreading', 'to', 'several', 'cities', 'including', 'the', 'capital', 'baghdad', 'iraqis', 'are', 'voicing', 'their', 'frustrations', 'over', 'widespread', 'unemployment', 'pollution', 'dirty', 'drinking', 'water', 'and', 'electricity', 'failures', 'during', 'stifling', 'heat', 'wave', 'in', 'the', 'country', 'south', 'while', 'many', 'of', 'the', 'protests', 'have', 'been', 'peaceful', 'others', 'have']...
# Query: 'How did Alexander Van der Bellen's victory in the Austrian election impact European politics?'
# Top documents:
#  - Document 750: ['the', 'european', 'union', 'is', 'facing', 'fresh', 'turmoil', 'as', 'italy', 'prime', 'minister', 'matteo', 'renzi', 'announced', 'his', 'resignation', 'after', 'suffering', 'decisive', 'defeat', 'in', 'his', 'constitutional', 'reform', 'referendum', 'ninety', 'minutes', 'after', 'polls', 'closed', 'the', 'year', 'premier', 'conceded', 'defeat', 'as', 'exit', 'polls', 'suggested', 'of', 'voters', 'had', 'rejected', 'his', 'plan', 'to', 'streamline', 'the', 'country', 'system', 'of', 'government', 'financial', 'markets', 'were', 'braced', 'for', 'fresh', 'volatility', 'amid', 'fears', 'his', 'fall', 'could', 'spark', 'run', 'on', 'italy', 'tottering', 'banks', 'further', 'weakening', 'the', 'euro', 'the', 'result', 'will', 'be', 'seen', 'as', 'further', 'victory', 'for', 'the', 'anti', 'establishment', 'backlash', 'sweeping', 'much', 'of', 'europe', 'and', 'america', 'with', 'the', 'opposition', 'to', 'his', 'plan', 'headed']...
#  - Document 2234: ['related', 'media', 'assets', 'image', 'or', 'videos', 'available', 'click', 'to', 'see', 'the', 'gallery', 'related', 'media', 'assets', 'image', 'or', 'videos', 'available', 'click', 'to', 'see', 'the', 'gallery', 'belgian', 'prime', 'minister', 'charles', 'michel', 'said', 'his', 'government', 'would', 'continue', 'as', 'minority', 'administration', 'after', 'the', 'biggest', 'party', 'in', 'his', 'coalition', 'quit', 'on', 'saturday', 'in', 'row', 'over', 'signing', 'the', 'migration', 'compact', 'brussels', 'belgian', 'prime', 'minister', 'charles', 'michel', 'said', 'his', 'government', 'would', 'continue', 'as', 'minority', 'administration', 'after', 'the', 'biggest', 'party', 'in', 'his', 'coalition', 'quit', 'on', 'saturday', 'in', 'row', 'over', 'signing', 'the', 'migration', 'compact', 'michel', 'french', 'speaking', 'liberal', 'said', 'he', 'took', 'note', 'of', 'the', 'departure', 'of', 'the', 'flemish', 'va']...
#  - Document 3119: ['millions', 'of', 'people', 'across', 'the', 'uk', 'are', 'set', 'to', 'vote', 'in', 'the', 'general', 'election', 'on', 'thursday', 'where', 'the', 'ruling', 'conservatives', 'are', 'predicted', 'to', 'secure', 'an', 'overall', 'majority', 'despite', 'an', 'energetic', 'bid', 'for', 'power', 'by', 'the', 'opposition', 'labour', 'party', 'the', 'media', 'reported', 'voting', 'will', 'begin', 'at', 'local', 'time', 'in', 'over', 'polling', 'stations', 'across', 'the', 'country', 'the', 'bbc', 'reported', 'counting', 'will', 'start', 'once', 'the', 'voting', 'ends', 'at', 'total', 'of', 'westminster', 'mps', 'will', 'be', 'elected', 'with', 'about', 'million', 'people', 'registered', 'to', 'vote', 'some', 'votes', 'have', 'already', 'been', 'cast', 'through', 'postal', 'voting', 'handful', 'of', 'seats', 'will', 'be', 'declared', 'by', 'thursday', 'midnight', 'with', 'the', 'final']...
#  - Document 1061: ['the', 'national', 'front', 'far', 'right', 'presidential', 'candidate', 'marine', 'le', 'pen', 'is', 'trying', 'to', 'pick', 'off', 'supporters', 'of', 'françois', 'fillon', 'the', 'center', 'right', 'republican', 'candidate', 'who', 'came', 'up', 'short', 'in', 'the', 'first', 'round', 'of', 'the', 'french', 'elections', 'in', 'hopes', 'of', 'of', 'pulling', 'off', 'an', 'upset', 'and', 'defeating', 'her', 'opponent', 'centrist', 'emmanuel', 'macron', 'in', 'this', 'weekend', 'runoff', 'but', 'her', 'strategy', 'to', 'peel', 'away', 'fillon', 'fans', 'has', 'run', 'into', 'quite', 'the', 'hiccup', 'she', 'now', 'been', 'accused', 'of', 'plagiarizing', 'whole', 'excerpts', 'from', 'recent', 'fillon', 'speech', 'fillon', 'gave', 'his', 'speech', 'on', 'april', 'shortly', 'before', 'the', 'first', 'round', 'of', 'the', 'elections', 'le', 'pen', 'delivered', 'her', 'version']...
#  - Document 4095: ['these', 'three', 'things', 'will', 'change', 'the', 'world', 'today', 'brexit', 'day', 'is', 'here', 'article', 'will', 'be', 'filed', 'today', 'the', 'british', 'prime', 'minister', 'theresa', 'may', 'has', 'launched', 'the', 'proceedings', 'that', 'will', 'see', 'the', 'uk', 'officially', 'withdraw', 'from', 'the', 'european', 'union', 'under', 'article', 'proceedings', 'may', 'has', 'to', 'formally', 'notify', 'eu', 'council', 'president', 'donald', 'tusk', 'that', 'the', 'uk', 'is', 'leaving', 'the', 'eu', 'in', 'letter', 'may', 'has', 'two', 'years', 'to', 'decide', 'the', 'leaving', 'terms', 'with', 'the', 'union', 'before', 'march', 'when', 'the', 'relationship', 'is', 'officially', 'terminated', 'in', 'speech', 'today', 'the', 'prime', 'minister', 'is', 'expected', 'to', 'say', 'now', 'that', 'the', 'decision', 'has', 'been', 'made', 'to', 'leave', 'the']...
# Query: 'What are the implications of the U.S. Supreme Court’s ruling in Salman v. U.S. for insider trading laws?'
# Top documents:
#  - Document 4105: ['bassam', 'salman', 'chicago', 'grocery', 'wholesaler', 'received', 'stock', 'tips', 'from', 'friend', 'who', 'had', 'in', 'turn', 'received', 'inside', 'information', 'from', 'salman', 'brother', 'in', 'law', 'an', 'investment', 'banker', 'at', 'citigroup', 'salman', 'made', 'hundreds', 'of', 'thousands', 'of', 'dollars', 'from', 'the', 'tips', 'but', 'he', 'was', 'also', 'charged', 'with', 'insider', 'trading', 'and', 'sentenced', 'to', 'three', 'years', 'in', 'prison', 'today', 'the', 'supreme', 'court', 'upheld', 'salman', 'conviction', 'rejecting', 'his', 'argument', 'that', 'he', 'could', 'not', 'be', 'held', 'liable', 'because', 'his', 'brother', 'in', 'law', 'had', 'not', 'received', 'any', 'financial', 'benefits', 'in', 'exchange', 'for', 'the', 'inside', 'information', 'that', 'he', 'disclosed', 'the', 'unanimous', 'ruling', 'which', 'came', 'just', 'over', 'two', 'months', 'after', 'the']...
#  - Document 159: ['media', 'playback', 'is', 'unsupported', 'on', 'your', 'device', 'media', 'caption', 'finally', 'glad', 'can', 'say', 'not', 'criminal', 'in', 'this', 'country', 'anymore', 'in', 'historic', 'decision', 'india', 'supreme', 'court', 'has', 'ruled', 'that', 'gay', 'sex', 'is', 'no', 'longer', 'criminal', 'offence', 'the', 'ruling', 'overturns', 'judgement', 'that', 'upheld', 'colonial', 'era', 'law', 'known', 'as', 'section', 'under', 'which', 'gay', 'sex', 'is', 'categorised', 'as', 'an', 'unnatural', 'offence', 'the', 'court', 'has', 'now', 'ruled', 'discrimination', 'on', 'the', 'basis', 'of', 'sexual', 'orientation', 'is', 'fundamental', 'violation', 'of', 'rights', 'campaigners', 'outside', 'the', 'court', 'cheered', 'and', 'some', 'broke', 'down', 'in', 'tears', 'as', 'the', 'ruling', 'was', 'handed', 'down', 'although', 'public', 'opinion', 'in', 'india', 'biggest', 'cities', 'has', 'been']...
#  - Document 4353: ['cnn', 'another', 'federal', 'court', 'has', 'ruled', 'against', 'president', 'donald', 'trump', 'revised', 'executive', 'order', 'limiting', 'travel', 'from', 'six', 'predominately', 'muslim', 'countries', 'and', 'like', 'other', 'courts', 'used', 'his', 'tweets', 'against', 'him', 'the', 'ruling', 'from', 'three', 'judge', 'panel', 'of', 'the', 'ninth', 'circuit', 'court', 'of', 'appeals', 'is', 'yet', 'another', 'stinging', 'loss', 'from', 'court', 'that', 'similarly', 'refused', 'to', 'reinstate', 'trump', 'original', 'executive', 'order', 'on', 'travel', 'in', 'february', 'we', 'conclude', 'that', 'the', 'president', 'in', 'issuing', 'the', 'executive', 'order', 'exceeded', 'the', 'scope', 'of', 'the', 'authority', 'delegated', 'to', 'him', 'by', 'congress', 'the', 'three', 'judges', 'all', 'appointed', 'by', 'president', 'bill', 'clinton', 'wrote', 'mmigration', 'even', 'for', 'the', 'president', 'is', 'not']...
#  - Document 2732: ['this', 'story', 'is', 'from', 'may', 'protesters', 'against', 'triple', 'talaq', 'photo', 'pti', 'islamic', 'practice', 'of', 'triple', 'talaq', 'we', 'would', 'not', 'interfere', 'new', 'delhi', 'as', 'historic', 'hearing', 'began', 'today', 'at', 'the', 'supreme', 'court', 'on', 'the', 'the', 'top', 'court', 'started', 'proceedings', 'by', 'making', 'it', 'very', 'clear', 'that', 'it', 'only', 'going', 'to', 'rule', 'on', 'the', 'constitutional', 'validity', 'of', 'oral', 'divorce', 'and', 'not', 'on', 'polygamy', 'the', 'top', 'court', 'said', 'it', 'will', 'determine', 'whether', 'triple', 'talaq', 'is', 'part', 'of', 'the', 'fundamental', 'right', 'to', 'religion', 'of', 'the', 'muslim', 'community', 'if', 'we', 'come', 'to', 'conclusion', 'that', 'triple', 'talaq', 'is', 'part', 'of', 'the', 'fundamental', 'right', 'to', 'religion', 'the', 'apex']...
#  - Document 4998: ['the', 'ninth', 'circuit', 'court', 'of', 'appeals', 'has', 'just', 'released', 'unanimous', 'ruling', 'denying', 'president', 'trump', 'motion', 'for', 'stay', 'of', 'the', 'lower', 'court', 'injunction', 'against', 'president', 'trump', 'executive', 'order', 'temporarily', 'suspending', 'visa', 'from', 'seven', 'nations', 'of', 'concern', 'we', 'are', 'looking', 'for', 'the', 'full', 'ruling', 'document', 'update', 'full', 'ruling', 'pdf', 'below', 'president', 'trump', 'has', 'two', 'options', 'on', 'this', 'specific', 'xo', 'request', 'direct', 'appeal', 'on', 'this', 'decision', 'to', 'supreme', 'court', 'justice', 'john', 'brennan', 'who', 'oversees', 'the', 'ninth', 'circuit', 'or', 'take', 'the', 'appeal', 'to', 'the', 'full', 'supreme', 'court', 'additionally', 'president', 'trump', 'may', 'choose', 'to', 'rewrite', 'the', 'initial', 'executive', 'order', 'and', 'clarify', 'the', 'purpose', 'and', 'intent']...
# Query: 'What challenges remain after Colombia’s peace accord with FARC was signed?'
# Top documents:
#  - Document 562: ['bogota', 'colombian', 'president', 'juan', 'manuel', 'santos', 'said', 'that', 'ceasefire', 'with', 'farc', 'rebels', 'will', 'end', 'on', 'october', 'as', 'both', 'sides', 'scramble', 'to', 'find', 'solution', 'to', 'the', 'half', 'century', 'conflict', 'after', 'voters', 'rejected', 'peace', 'deal', 'the', 'chief', 'of', 'the', 'revolutionary', 'armed', 'forces', 'of', 'colombia', 'farc', 'rodrigo', 'londono', 'better', 'known', 'as', 'timoleon', 'timochenko', 'jimenez', 'promptly', 'took', 'to', 'twitter', 'to', 'ask', 'and', 'after', 'that', 'the', 'war', 'continues', 'just', 'day', 'earlier', 'he', 'had', 'vowed', 'the', 'guerrillas', 'would', 'continue', 'to', 'observe', 'the', 'ceasefire', 'despite', 'the', 'referendum', 'results', 'hope', 'we', 'can', 'move', 'forward', 'to', 'realize', 'the', 'necessary', 'agreement', 'to', 'find', 'solution', 'to', 'this', 'conflict', 'santos', 'said', 'in']...
#  - Document 334: ['bogota', 'reuters', 'colombia', 'president', 'juan', 'manuel', 'santos', 'and', 'marxist', 'farc', 'rebel', 'leader', 'rodrigo', 'londono', 'signed', 'revised', 'peace', 'accord', 'on', 'thursday', 'in', 'far', 'more', 'sober', 'ceremony', 'than', 'first', 'deal', 'rejected', 'last', 'month', 'by', 'millions', 'at', 'plebiscite', 'as', 'they', 'inked', 'the', 'pact', 'with', 'pen', 'made', 'from', 'bullet', 'at', 'historic', 'bogota', 'theater', 'onlookers', 'chanted', 'we', 'did', 'it', 'the', 'new', 'accord', 'to', 'end', 'years', 'of', 'war', 'in', 'latin', 'america', 'fourth', 'largest', 'economy', 'was', 'put', 'together', 'in', 'just', 'over', 'month', 'after', 'the', 'original', 'pact', 'was', 'narrowly', 'and', 'unexpectedly', 'defeated', 'in', 'an', 'oct', 'referendum', 'for', 'being', 'too', 'lenient', 'on', 'the', 'rebels', 'the', 'government', 'and', 'revolutionary', 'armed']...
#  - Document 349: ['bogota', 'reuters', 'colombia', 'president', 'juan', 'manuel', 'santos', 'on', 'thursday', 'extended', 'his', 'ceasefire', 'with', 'marxist', 'farc', 'rebels', 'through', 'the', 'end', 'of', 'the', 'year', 'as', 'he', 'seeks', 'to', 'revive', 'peace', 'accord', 'to', 'end', 'five', 'decades', 'of', 'war', 'after', 'voters', 'rejected', 'the', 'hard', 'fought', 'deal', 'in', 'referendum', 'colombia', 'president', 'juan', 'manuel', 'santos', 'speaks', 'to', 'guests', 'after', 'receiving', 'the', 'clinton', 'global', 'citizen', 'award', 'in', 'new', 'york', 'september', 'reuters', 'eduardo', 'munoz', 'file', 'photo', 'the', 'original', 'ceasefire', 'which', 'was', 'put', 'in', 'place', 'in', 'august', 'was', 'nullified', 'when', 'the', 'peace', 'accord', 'was', 'rejected', 'in', 'plebiscite', 'earlier', 'this', 'month', 'he', 'had', 'already', 'extended', 'it', 'to', 'oct', 'the', 'decision']...
#  - Document 5782: ['the', 'nobel', 'peace', 'prize', 'of', 'is', 'set', 'to', 'be', 'awarded', 'to', 'colombian', 'president', 'juan', 'manuel', 'santos', 'who', 'called', 'it', 'gift', 'from', 'heaven', 'for', 'his', 'country', 'peace', 'process', 'with', 'farc', 'rebels', 'the', 'prize', 'ceremony', 'will', 'be', 'held', 'on', 'saturday', 'evening', 'in', 'the', 'norwegian', 'capital', 'oslo', 'al', 'jazeera', 'will', 'be', 'talking', 'exclusively', 'to', 'the', 'colombian', 'president', 'at', 'gmt', 'watch', 'the', 'interview', 'live', 'here', 'the', 'norwegian', 'nobel', 'committee', 'decided', 'to', 'award', 'the', 'prize', 'to', 'santos', 'for', 'his', 'resolute', 'efforts', 'to', 'bring', 'the', 'country', 'more', 'than', 'year', 'long', 'conflict', 'with', 'the', 'revolutionary', 'armed', 'forces', 'of', 'colombia', 'farc', 'to', 'an', 'end', 'the', 'war', 'has', 'cost']...
#  - Document 7214: ['image', 'copyright', 'getty', 'images', 'image', 'caption', 'the', 'first', 'peace', 'deal', 'met', 'resistance', 'as', 'many', 'claimed', 'it', 'allowed', 'farc', 'rebels', 'to', 'get', 'away', 'with', 'murder', 'the', 'colombian', 'government', 'and', 'the', 'farc', 'rebel', 'group', 'have', 'announced', 'new', 'peace', 'agreement', 'six', 'weeks', 'after', 'the', 'original', 'deal', 'was', 'rejected', 'in', 'popular', 'vote', 'the', 'two', 'sides', 'which', 'have', 'been', 'holding', 'talks', 'in', 'cuba', 'for', 'four', 'years', 'said', 'the', 'revised', 'plan', 'incorporated', 'proposals', 'from', 'the', 'opposition', 'and', 'others', 'groups', 'the', 'initial', 'deal', 'had', 'been', 'deemed', 'to', 'be', 'too', 'favourable', 'to', 'the', 'left', 'wing', 'rebels', 'the', 'new', 'agreement', 'is', 'not', 'expected', 'to', 'be', 'put', 'to', 'another', 'popular']...
# Query: 'How are Egyptian authorities responding to the recent killing of a policeman in Cairo?'
# Top documents:
#  - Document 416: ['gunmen', 'on', 'motorcycle', 'opened', 'fire', 'on', 'security', 'vehicle', 'friday', 'killing', 'five', 'policemen', 'just', 'short', 'distance', 'from', 'some', 'of', 'egypt', 'oldest', 'pyramids', 'in', 'giza', 'officials', 'said', 'the', 'shooting', 'in', 'the', 'early', 'hours', 'of', 'the', 'morning', 'took', 'place', 'in', 'the', 'village', 'of', 'abusir', 'in', 'badrashin', 'part', 'of', 'greater', 'cairo', 'and', 'the', 'slain', 'policemen', 'were', 'part', 'of', 'the', 'force', 'tasked', 'to', 'guard', 'the', 'district', 'of', 'saqqara', 'one', 'of', 'egypt', 'most', 'popular', 'tourist', 'sites', 'and', 'host', 'to', 'collection', 'of', 'temples', 'tombs', 'and', 'funerary', 'complexes', 'authorities', 'cordoned', 'off', 'the', 'area', 'and', 'ambulances', 'rushed', 'to', 'the', 'site', 'of', 'the', 'attack', 'which', 'is', 'located', 'near', 'the', 'famous']...
#  - Document 4437: ['egyptian', 'security', 'forces', 'have', 'killed', 'suspected', 'terrorists', 'in', 'raids', 'on', 'their', 'hideouts', 'just', 'day', 'after', 'tourist', 'bus', 'bombing', 'three', 'vietnamese', 'holidaymakers', 'and', 'local', 'guide', 'died', 'in', 'the', 'blast', 'just', 'short', 'distance', 'from', 'the', 'pyramids', 'in', 'giza', 'another', 'suspected', 'militants', 'were', 'killed', 'in', 'north', 'sinai', 'where', 'the', 'country', 'fighting', 'an', 'insurgency', 'led', 'by', 'islamic', 'state', 'two', 'vietnamese', 'tourists', 'and', 'tour', 'guide', 'were', 'killed', 'and', 'cairo', 'egyptian', 'security', 'forces', 'killed', 'at', 'least', 'people', 'suspected', 'of', 'being', 'militants', 'in', 'north', 'sinai', 'and', 'giza', 'officials', 'said', 'on', 'saturday', 'day', 'after', 'an', 'explosion', 'hit', 'tour', 'bus', 'leaving', 'four', 'people', 'dead', 'and', 'others', 'wounded', 'the', 'ministry']...
#  - Document 1623: ['egyptian', 'forces', 'have', 'struck', 'terrorist', 'training', 'camps', 'in', 'retaliation', 'for', 'an', 'attack', 'on', 'coptic', 'christians', 'president', 'abdul', 'fattah', 'al', 'sisi', 'has', 'said', 'state', 'media', 'say', 'six', 'strikes', 'hit', 'the', 'town', 'of', 'derna', 'in', 'neighbouring', 'libya', 'gunmen', 'earlier', 'attacked', 'bus', 'carrying', 'worshippers', 'in', 'central', 'egypt', 'killing', 'at', 'least', 'people', 'and', 'wounding', 'others', 'president', 'sisi', 'said', 'he', 'would', 'not', 'hesitate', 'to', 'strike', 'terrorist', 'camps', 'anywhere', 'announcing', 'the', 'strike', 'in', 'tv', 'speech', 'late', 'on', 'friday', 'he', 'promised', 'to', 'protect', 'our', 'people', 'from', 'the', 'evil', 'countries', 'supporting', 'terrorism', 'should', 'be', 'punished', 'he', 'said', 'as', 'he', 'appealed', 'to', 'us', 'president', 'donald', 'trump', 'for', 'help', 'military']...
#  - Document 6934: ['three', 'bombs', 'exploded', 'saturday', 'morning', 'in', 'sittwe', 'the', 'capital', 'of', 'myanmar', 'troubled', 'rakhine', 'state', 'authorities', 'said', 'one', 'of', 'the', 'explosions', 'injured', 'police', 'officer', 'but', 'no', 'other', 'casualties', 'have', 'been', 'reported', 'authorities', 'are', 'working', 'to', 'determine', 'who', 'was', 'behind', 'the', 'bombings', 'police', 'said', 'three', 'unexploded', 'devices', 'targeting', 'government', 'offices', 'and', 'other', 'places', 'were', 'seized', 'at', 'other', 'locations', 'in', 'sittwe', 'the', 'blasts', 'come', 'three', 'days', 'after', 'bomb', 'explosion', 'killed', 'two', 'bank', 'employees', 'and', 'injured', 'about', 'two', 'dozen', 'people', 'in', 'the', 'northeastern', 'city', 'of', 'lashio', 'where', 'several', 'ethnic', 'insurgent', 'groups', 'are', 'fighting', 'the', 'myanmar', 'military', 'last', 'month', 'at', 'least', 'seven', 'rakhine', 'buddhists', 'were']...
#  - Document 261: ['kaduna', 'nigeria', 'reuters', 'kidnappers', 'have', 'abducted', 'two', 'americans', 'and', 'two', 'canadians', 'in', 'the', 'northern', 'nigerian', 'state', 'of', 'kaduna', 'killing', 'two', 'police', 'officers', 'police', 'spokesman', 'said', 'on', 'wednesday', 'kidnappings', 'are', 'rife', 'in', 'nigeria', 'where', 'domestic', 'security', 'is', 'weak', 'though', 'they', 'overwhelmingly', 'target', 'other', 'nigerians', 'however', 'abductions', 'of', 'foreigners', 'are', 'not', 'uncommon', 'the', 'foreigners', 'were', 'ambushed', 'by', 'unknown', 'gunmen', 'on', 'their', 'way', 'from', 'the', 'town', 'of', 'kafanchan', 'in', 'kaduna', 'state', 'to', 'the', 'capital', 'abuja', 'mukhtar', 'aliyu', 'spokesman', 'for', 'the', 'kaduna', 'state', 'police', 'said', 'by', 'telephone', 'kafanchan', 'is', 'about', 'hours', 'drive', 'northeast', 'of', 'abuja', 'the', 'two', 'police', 'escorts', 'attached', 'to', 'them', 'engaged', 'the']...
# Query: 'What are the safety protocols in place at the New York City Metropolitan Opera after a recent disruption?'
# Top documents:
#  - Document 853: ['joseph', 'lhota', 'the', 'chairman', 'of', 'the', 'transportation', 'authority', 'pointed', 'out', 'that', 'rebuilding', 'the', 'station', 'had', 'been', 'complex', 'project', 'requiring', 'working', 'with', 'other', 'state', 'and', 'city', 'agencies', 'and', 'developers', 'to', 'determine', 'where', 'the', 'new', 'buildings', 'were', 'going', 'to', 'be', 'located', 'before', 'they', 'could', 'even', 'begin', 'to', 'plan', 'subway', 'entrances', 'remember', 'there', 'was', 'lot', 'of', 'construction', 'he', 'said', 'these', 'entranceways', 'would', 'have', 'been', 'in', 'the', 'middle', 'of', 'construction', 'sites', 'where', 'there', 'were', 'cranes', 'and', 'all', 'of', 'that', 'safety', 'is', 'one', 'of', 'the', 'most', 'important', 'things', 'that', 'we', 'deal', 'with', 'every', 'single', 'day', 'here', 'lower', 'manhattan', 'has', 'rebounded', 'and', 'thrived', 'in', 'the', 'years']...
#  - Document 5124: ['collapsed', 'shopping', 'center', 'in', 'mexico', 'city', 'mexico', 'is', 'seen', 'in', 'this', 'july', 'image', 'obtained', 'from', 'social', 'media', 'jessica', 'cruz', 'via', 'reuters', 'mexico', 'city', 'reuters', 'portion', 'of', 'multilevel', 'luxury', 'shopping', 'center', 'in', 'mexico', 'city', 'collapsed', 'on', 'thursday', 'sending', 'debris', 'flying', 'and', 'kicking', 'up', 'clouds', 'of', 'gray', 'dust', 'television', 'images', 'showed', 'no', 'deaths', 'or', 'injuries', 'were', 'immediately', 'reported', 'at', 'the', 'site', 'mexico', 'civil', 'protection', 'agency', 'said', 'the', 'shopping', 'center', 'called', 'artz', 'pedregal', 'in', 'the', 'south', 'of', 'the', 'capital', 'opened', 'in', 'march', 'according', 'to', 'local', 'media', 'mexico', 'city', 'head', 'of', 'civil', 'protection', 'fausto', 'lugo', 'said', 'that', 'the', 'cause', 'was', 'structural', 'but', 'that', 'experts']...
#  - Document 4654: ['california', 'woman', 'is', 'denying', 'that', 'she', 'or', 'her', 'husband', 'abused', 'their', 'children', 'after', 'authorities', 'said', 'the', 'kids', 'suffered', 'puncture', 'wounds', 'burns', 'and', 'injuries', 'consistent', 'with', 'being', 'shot', 'with', 'pellet', 'gun', 'california', 'woman', 'is', 'denying', 'that', 'she', 'or', 'her', 'husband', 'abused', 'their', 'children', 'after', 'authorities', 'said', 'the', 'kids', 'suffered', 'puncture', 'wounds', 'burns', 'and', 'injuries', 'consistent', 'with', 'being', 'shot', 'with', 'pellet', 'gun', 'glowing', 'taraji', 'henson', 'is', 'talking', 'about', 'how', 'she', 'first', 'fell', 'for', 'her', 'new', 'fiance', 'super', 'bowl', 'winner', 'kelvin', 'hayden', 'glowing', 'taraji', 'henson', 'is', 'talking', 'about', 'how', 'she', 'first', 'fell', 'for', 'her', 'new', 'fiance', 'super', 'bowl', 'winner', 'kelvin', 'hayden', 'heard', 'angels']...
#  - Document 4586: ['image', 'copyright', 'pa', 'image', 'caption', 'planes', 'are', 'grounded', 'at', 'the', 'airport', 'following', 'the', 'discovery', 'of', 'the', 'device', 'an', 'operation', 'to', 'remove', 'kg', 'world', 'war', 'two', 'bomb', 'that', 'has', 'forced', 'the', 'closure', 'of', 'london', 'city', 'airport', 'will', 'continue', 'through', 'the', 'night', 'the', 'airport', 'has', 'been', 'shut', 'all', 'day', 'and', 'all', 'flights', 'cancelled', 'affecting', 'up', 'to', 'passengers', 'officials', 'said', 'the', 'bomb', 'was', 'found', 'at', 'george', 'dock', 'on', 'sunday', 'during', 'planned', 'work', 'at', 'the', 'east', 'london', 'airport', 'the', 'royal', 'navy', 'said', 'the', 'bomb', 'would', 'be', 'exploded', 'underwater', 'overnight', 'and', 'the', 'airport', 'should', 'reopen', 'on', 'tuesday', 'police', 'have', 'confirmed', 'families', 'who', 'were', 'evacuated', 'from']...
#  - Document 7103: ['bomb', 'threats', 'are', 'being', 'reported', 'across', 'the', 'country', 'six', 'bomb', 'threats', 'have', 'been', 'reported', 'in', 'york', 'county', 'today', 'and', 'bomb', 'threats', 'are', 'being', 'investigated', 'in', 'lancaster', 'county', 'according', 'to', 'york', 'county', 'spokesman', 'mark', 'walters', 'and', 'the', 'lancaster', 'county', 'district', 'attorney', 'office', 'string', 'of', 'threats', 'have', 'been', 'made', 'nationwide', 'today', 'to', 'universities', 'including', 'penn', 'state', 'buildings', 'in', 'state', 'college', 'police', 'departments', 'and', 'news', 'outlets', 'it', 'appears', 'to', 'be', 'electronic', 'hoax', 'that', 'sent', 'officers', 'scrambling', 'the', 'penn', 'state', 'threats', 'are', 'reported', 'to', 'be', 'hoax', 'according', 'to', 'the', 'daily', 'collegian', 'six', 'businesses', 'or', 'organizations', 'in', 'york', 'county', 'have', 'received', 'the', 'threats', 'walters', 'said']...
# Query: 'What are the prospects for diplomatic relations between Iran and Canada following the release of Homa Hoodfar?'
# Top documents:
#  - Document 1807: ['baku', 'november', 'report', 'az', 'azerbaijan', 'and', 'south', 'africa', 'are', 'ready', 'to', 'sign', 'memorandums', 'which', 'will', 'cover', 'various', 'areas', 'including', 'air', 'transport', 'report', 'informs', 'minister', 'of', 'international', 'relations', 'and', 'cooperation', 'of', 'south', 'africa', 'maite', 'nkoana', 'mashabene', 'said', 'at', 'briefing', 'on', 'visit', 'to', 'azerbaijan', 'she', 'also', 'noted', 'that', 'south', 'africa', 'is', 'interested', 'in', 'raising', 'diplomatic', 'consultations', 'with', 'azerbaijan', 'to', 'the', 'inter', 'state', 'level', 'this', 'visit', 'has', 'substantive', 'results', 'on', 'which', 'we', 'can', 'continue', 'to', 'work', 'answering', 'the', 'question', 'of', 'reporters', 'nkoane', 'mashabane', 'also', 'said', 'that', 'south', 'africa', 'plans', 'to', 'open', 'diplomatic', 'mission', 'in', 'baku', 'baku', 'azerbaijan', 'apr', 'ani', 'india', 'and', 'azerbaijan', 'on']...
#  - Document 2311: ['ouagadougou', 'taipei', 'reuters', 'taiwan', 'lost', 'its', 'second', 'diplomatic', 'ally', 'in', 'less', 'than', 'month', 'on', 'thursday', 'when', 'burkina', 'faso', 'said', 'it', 'had', 'cut', 'ties', 'with', 'the', 'self', 'ruled', 'island', 'following', 'intense', 'chinese', 'pressure', 'on', 'african', 'countries', 'to', 'break', 'with', 'what', 'it', 'regards', 'as', 'wayward', 'province', 'flags', 'of', 'taiwan', 'nd', 'and', 'burkina', 'faso', 'are', 'seen', 'inside', 'the', 'taiwan', 'ministry', 'of', 'foreign', 'affairs', 'in', 'taipei', 'taiwan', 'may', 'reuters', 'tyrone', 'siu', 'taiwan', 'now', 'has', 'only', 'one', 'diplomatic', 'ally', 'left', 'in', 'africa', 'the', 'tiny', 'kingdom', 'of', 'swaziland', 'and', 'formal', 'relations', 'with', 'just', 'countries', 'worldwide', 'many', 'of', 'them', 'poor', 'nations', 'in', 'central', 'america', 'and', 'the', 'pacific']...
#  - Document 4801: ['wuhan', 'china', 'reuters', 'the', 'leaders', 'of', 'china', 'and', 'india', 'agreed', 'to', 'open', 'new', 'chapter', 'in', 'their', 'relationship', 'on', 'saturday', 'after', 'an', 'informal', 'summit', 'just', 'months', 'after', 'dispute', 'over', 'stretch', 'of', 'their', 'high', 'altitude', 'himalayan', 'border', 'rekindled', 'fears', 'of', 'war', 'indian', 'prime', 'minister', 'narendra', 'modi', 'spent', 'around', 'hours', 'in', 'the', 'central', 'chinese', 'city', 'of', 'wuhan', 'for', 'meetings', 'with', 'president', 'xi', 'jinping', 'an', 'ice', 'breaking', 'trip', 'both', 'hoped', 'would', 'allow', 'candour', 'and', 'nurture', 'trust', 'billed', 'as', 'an', 'informal', 'get', 'together', 'rather', 'than', 'summit', 'the', 'two', 'men', 'held', 'talks', 'on', 'friday', 'that', 'lasted', 'far', 'longer', 'than', 'expected', 'and', 'on', 'saturday', 'chatted', 'over', 'tea']...
#  - Document 3160: ['afghan', 'president', 'ashraf', 'ghani', 'met', 'with', 'his', 'iranian', 'counterpart', 'hassan', 'rouhani', 'on', 'the', 'sidelines', 'of', 'the', 'sco', 'summit', 'in', 'china', 'discussed', 'expansion', 'of', 'bilateral', 'ties', 'presidential', 'palace', 'in', 'statement', 'said', 'that', 'the', 'meeting', 'of', 'the', 'two', 'leaders', 'took', 'place', 'in', 'chinese', 'port', 'city', 'of', 'qingdao', 'on', 'saturday', 'in', 'the', 'meeting', 'the', 'two', 'leaders', 'emphasized', 'expansion', 'of', 'bilateral', 'political', 'and', 'economic', 'relations', 'as', 'well', 'as', 'joint', 'efforts', 'against', 'international', 'terrorism', 'and', 'drug', 'trafficking', 'the', 'presidents', 'of', 'both', 'countries', 'assessed', 'the', 'economic', 'and', 'trade', 'relations', 'as', 'positive', 'and', 'stressed', 'on', 'the', 'continuation', 'of', 'economic', 'cooperation', 'the', 'statement', 'said', 'in', 'the', 'meeting', 'president']...
#  - Document 923: ['beijing', 'reuters', 'china', 'and', 'norway', 'signed', 'pact', 'on', 'friday', 'to', 'resume', 'free', 'trade', 'negotiations', 'marking', 'the', 'end', 'of', 'six', 'year', 'diplomatic', 'freeze', 'move', 'china', 'called', 'internationally', 'significant', 'against', 'the', 'backdrop', 'of', 'rise', 'in', 'protectionist', 'sentiment', 'worldwide', 'norway', 'prime', 'minister', 'erna', 'solberg', 'and', 'china', 'premier', 'li', 'keqiang', 'inspect', 'honour', 'guards', 'during', 'welcoming', 'ceremony', 'outside', 'the', 'great', 'hall', 'of', 'the', 'people', 'in', 'beijing', 'china', 'april', 'reuters', 'jason', 'lee', 'the', 'memorandum', 'of', 'understanding', 'was', 'one', 'of', 'six', 'pacts', 'covering', 'cooperation', 'on', 'economic', 'development', 'technology', 'health', 'science', 'and', 'sport', 'during', 'norwegian', 'prime', 'minister', 'erna', 'solberg', 'visit', 'to', 'china', 'the', 'first', 'since', 'the', 'countries', 'resumed']...
# Query: 'What were the key issues in The Gambia’s recent elections?'
# Top documents:
#  - Document 6317: ['media', 'playback', 'is', 'unsupported', 'on', 'your', 'device', 'media', 'caption', 'what', 'you', 'need', 'to', 'know', 'about', 'the', 'election', 'sunday', 'vote', 'for', 'new', 'president', 'in', 'the', 'democratic', 'republic', 'of', 'congo', 'has', 'been', 'hit', 'by', 'series', 'of', 'delays', 'that', 'have', 'left', 'people', 'frustrated', 'the', 'failure', 'of', 'new', 'electronic', 'voting', 'machines', 'in', 'some', 'polling', 'stations', 'was', 'one', 'of', 'the', 'challenges', 'polls', 'have', 'now', 'closed', 'in', 'an', 'election', 'that', 'is', 'expected', 'to', 'bring', 'the', 'country', 'first', 'peaceful', 'transfer', 'of', 'power', 'since', 'independence', 'in', 'president', 'joseph', 'kabila', 'is', 'stepping', 'down', 'after', 'years', 'in', 'power', 'the', 'final', 'result', 'is', 'expected', 'be', 'announced', 'in', 'week', 'time', 'the', 'election']...
#  - Document 7483: ['the', 'afghan', 'government', 'says', 'it', 'will', 'hold', 'presidential', 'elections', 'on', 'april', 'for', 'the', 'fourth', 'time', 'since', 'the', 'taliban', 'were', 'toppled', 'from', 'power', 'in', 'however', 'officials', 'have', 'warned', 'much', 'work', 'needs', 'to', 'happen', 'to', 'meet', 'that', 'timeline', 'during', 'televised', 'news', 'conference', 'on', 'wednesday', 'election', 'officials', 'said', 'the', 'vote', 'would', 'take', 'place', 'six', 'months', 'after', 'parliamentary', 'and', 'local', 'elections', 'scheduled', 'for', 'october', 'polls', 'which', 'have', 'been', 'marred', 'by', 'technical', 'and', 'organisational', 'issues', 'afghanistan', 'independent', 'election', 'commission', 'iec', 'said', 'security', 'and', 'funding', 'as', 'well', 'as', 'the', 'short', 'timeframe', 'between', 'elections', 'would', 'present', 'the', 'biggest', 'challenges', 'to', 'the', 'poll', 'security', 'is', 'an', 'issue', 'that']...
#  - Document 4879: ['sydney', 'reuters', 'papua', 'new', 'guinea', 'parliament', 'on', 'wednesday', 're', 'elected', 'peter', 'neill', 'as', 'prime', 'minister', 'ending', 'chaotic', 'election', 'campaign', 'marred', 'by', 'violence', 'which', 'analysts', 'fear', 'may', 'continue', 'amid', 'widespread', 'voter', 'unrest', 'file', 'photo', 'peter', 'neill', 'the', 'prime', 'minister', 'of', 'papua', 'new', 'guinea', 'png', 'speaks', 'during', 'the', 'opening', 'of', 'the', 'png', 'mining', 'and', 'petroleum', 'investment', 'conference', 'in', 'sydney', 'australia', 'december', 'reuters', 'david', 'gray', 'file', 'photo', 'while', 'neill', 'ruling', 'people', 'national', 'congress', 'party', 'was', 'unable', 'to', 'win', 'enough', 'seats', 'to', 'form', 'government', 'outright', 'in', 'elections', 'last', 'month', 'in', 'which', 'counting', 'continues', 'he', 'secured', 'enough', 'support', 'from', 'minor', 'parties', 'and', 'independent', 'lawmakers', 'to']...
#  - Document 6574: ['zimbabwe', 'opposition', 'leader', 'nelson', 'chamisa', 'said', 'on', 'tuesday', 'he', 'was', 'winning', 'the', 'election', 'resoundingly', 'as', 'votes', 'were', 'being', 'counted', 'in', 'the', 'first', 'election', 'since', 'robert', 'mugabe', 'was', 'ousted', 'from', 'power', 'mr', 'chamisha', 'said', 'on', 'twitter', 'winning', 'resoundingly', 'we', 'now', 'have', 'results', 'from', 'the', 'majority', 'of', 'the', 'over', 'polling', 'stations', 'we', 've', 'done', 'exceedingly', 'well', 'awaiting', 'zec', 'to', 'perform', 'their', 'constitutional', 'duty', 'to', 'officially', 'announce', 'the', 'people', 'election', 'results', 'and', 'we', 'are', 'ready', 'to', 'form', 'the', 'next', 'government', 'his', 'party', 'had', 'collected', 'results', 'from', 'more', 'than', 'polling', 'stations', 'which', 'showed', 'the', 'mdc', 'had', 'done', 'exceedingly', 'well', 'and', 'was', 'ready', 'to', 'form']...
# ...
#  - Document 633: ['army', 'completes', 'clearance', 'operation', 'which', 'un', 'says', 'has', 'caused', 'people', 'to', 'flee', 'to', 'bangladesh', 'this', 'article', 'is', 'more', 'than', 'years', 'old', 'this', 'article', 'is', 'more', 'than', 'years', 'old', 'myanmar', 'military', 'has', 'ended', 'clearance', 'operation', 'in', 'the', 'country', 'troubled', 'rakhine', 'state', 'government', 'officials', 'said', 'ending', 'four', 'month', 'sweep', 'that', 'the', 'united', 'nations', 'said', 'may', 'amount', 'to', 'crimes', 'against', 'humanity', 'and', 'possibly', 'ethnic', 'cleansing', 'the', 'security', 'operation', 'began', 'in', 'october', 'when', 'nine', 'policemen', 'were', 'killed', 'in', 'attacks', 'on', 'security', 'posts', 'near', 'the', 'bangladesh', 'border', 'almost', 'rohingyas', 'have', 'since', 'fled', 'from', 'myanmar', 'to', 'bangladesh', 'according', 'to', 'un', 'estimates', 'the', 'violence', 'has', 'renewed', 'international']...
# Query: 'How does the Austrian election reflect broader political trends in Europe?'
# Top documents:
#  - Document 1959: ['why', 'did', 'this', 'happen', 'please', 'make', 'sure', 'your', 'browser', 'supports', 'javascript', 'and', 'cookies', 'and', 'that', 'you', 'are', 'not', 'blocking', 'them', 'from', 'loading', 'for', 'more', 'information', 'you', 'can', 'review', 'our', 'terms', 'of', 'service', 'and', 'cookie', 'policy', 'merkel', 'rejects', 'us', 'comments', 'says', 'germany', 'cannot', 'influence', 'euro', 'german', 'chancellor', 'angela', 'merkel', 'left', 'and', 'swedish', 'prime', 'minister', 'stefan', 'lofven', 'right', 'are', 'shown', 'an', 'industrial', 'robot', 'by', 'johan', 'soderstrom', 'centre', 'ceo', 'of', 'abb', 'sweden', 'during', 'visit', 'at', 'the', 'royal', 'swedish', 'academy', 'of', 'engineering', 'sciences', 'in', 'stockholm', 'sweden', 'january', 'reuters', 'picstockholm', 'jan', 'chancellor', 'angela', 'merkel', 'today', 'rejected', 'us', 'trade', 'adviser', 'charge', 'that', 'germany', 'was', 'using', 'an']...
#  - Document 750: ['the', 'european', 'union', 'is', 'facing', 'fresh', 'turmoil', 'as', 'italy', 'prime', 'minister', 'matteo', 'renzi', 'announced', 'his', 'resignation', 'after', 'suffering', 'decisive', 'defeat', 'in', 'his', 'constitutional', 'reform', 'referendum', 'ninety', 'minutes', 'after', 'polls', 'closed', 'the', 'year', 'premier', 'conceded', 'defeat', 'as', 'exit', 'polls', 'suggested', 'of', 'voters', 'had', 'rejected', 'his', 'plan', 'to', 'streamline', 'the', 'country', 'system', 'of', 'government', 'financial', 'markets', 'were', 'braced', 'for', 'fresh', 'volatility', 'amid', 'fears', 'his', 'fall', 'could', 'spark', 'run', 'on', 'italy', 'tottering', 'banks', 'further', 'weakening', 'the', 'euro', 'the', 'result', 'will', 'be', 'seen', 'as', 'further', 'victory', 'for', 'the', 'anti', 'establishment', 'backlash', 'sweeping', 'much', 'of', 'europe', 'and', 'america', 'with', 'the', 'opposition', 'to', 'his', 'plan', 'headed']...
#  - Document 1972: ['hungarian', 'prime', 'minister', 'viktor', 'orbán', 'and', 'his', 'populist', 'fidesz', 'party', 'easily', 'swept', 'to', 'victory', 'on', 'sunday', 'in', 'parliamentary', 'election', 'that', 'saw', 'the', 'highest', 'turnout', 'of', 'voters', 'in', 'more', 'than', 'decade', 'it', 'will', 'be', 'the', 'third', 'successive', 'term', 'for', 'orbán', 'who', 'is', 'the', 'longest', 'serving', 'prime', 'minister', 'in', 'post', 'communist', 'hungary', 'it', 'the', 'year', 'old', 'fourth', 'term', 'overall', 'his', 'party', 'is', 'projected', 'to', 'regain', 'its', 'two', 'thirds', 'majority', 'in', 'the', 'seat', 'parliament', 'we', 'scored', 'decisive', 'victory', 'orbán', 'told', 'his', 'supporters', 'we', 'have', 'received', 'an', 'opportunity', 'created', 'an', 'opportunity', 'to', 'be', 'able', 'to', 'defend', 'hungary', 'budapest', 'voter', 'katalin', 'andrássy', 'said', 'she', 'cast']...
#  - Document 4524: ['german', 'chancellor', 'angela', 'merkel', 'on', 'monday', 'defended', 'her', 'government', 'handling', 'of', 'the', 'refugee', 'crisis', 'but', 'said', 'the', 'poor', 'election', 'result', 'showed', 'there', 'was', 'work', 'to', 'be', 'done', 'to', 'win', 'back', 'voter', 'confidence', 'am', 'very', 'unsatisfied', 'with', 'the', 'outcome', 'of', 'the', 'election', 'merkel', 'told', 'reporters', 'on', 'the', 'sidelines', 'of', 'the', 'summit', 'in', 'china', 'obviously', 'it', 'has', 'something', 'to', 'do', 'with', 'the', 'refugee', 'question', 'but', 'nevertheless', 'believe', 'the', 'decisions', 'made', 'were', 'right', 'and', 'we', 'have', 'to', 'continue', 'to', 'work', 'on', 'them', 'merkel', 'conservative', 'christian', 'democratic', 'union', 'cdu', 'was', 'relegated', 'to', 'third', 'place', 'behind', 'the', 'right', 'wing', 'anti', 'immigrant', 'alternative', 'for', 'germany', 'afd']...
#  - Document 2178: ['woman', 'passes', 'in', 'front', 'pre', 'election', 'poster', 'of', 'bulgaria', 'centre', 'right', 'ruling', 'gerb', 'party', 'presidential', 'candidate', 'tsetska', 'tsacheva', 'and', 'vice', 'president', 'plamen', 'manushev', 'right', 'in', 'sofia', 'friday', 'nov', 'more', 'woman', 'passes', 'in', 'front', 'pre', 'election', 'poster', 'of', 'bulgaria', 'centre', 'right', 'ruling', 'gerb', 'party', 'presidential', 'candidate', 'tsetska', 'tsacheva', 'and', 'vice', 'president', 'plamen', 'manushev', 'right', 'in', 'sofia', 'friday', 'nov', 'bulgarians', 'will', 'to', 'choose', 'their', 'new', 'president', 'on', 'sunday', 'to', 'replace', 'incumbent', 'rosen', 'plevneliev', 'after', 'his', 'five', 'year', 'term', 'ends', 'next', 'january', 'the', 'election', 'campaign', 'focused', 'mainly', 'on', 'the', 'future', 'of', 'the', 'european', 'union', 'relations', 'with', 'russia', 'and', 'the', 'threats', 'from', 'possible', 'rise']...
# Query: 'What steps are being taken to prevent further incidents like the Metropolitan Opera disruption?'
# Top documents:
#  - Document 7164: ['image', 'copyright', 'roxane', 'wephre', 'image', 'caption', 'police', 'are', 'not', 'treating', 'the', 'crash', 'as', 'being', 'terrorist', 'related', 'three', 'people', 'were', 'taken', 'to', 'hospital', 'after', 'car', 'ploughed', 'into', 'large', 'group', 'of', 'people', 'outside', 'north', 'london', 'pub', 'witnesses', 'reported', 'bodies', 'being', 'thrown', 'in', 'the', 'air', 'when', 'the', 'car', 'mounted', 'the', 'pavement', 'outside', 'the', 'old', 'queen', 'head', 'in', 'islington', 'on', 'saturday', 'night', 'two', 'knives', 'were', 'found', 'at', 'the', 'scene', 'but', 'police', 'said', 'they', 'are', 'not', 'treating', 'the', 'crash', 'as', 'terrorist', 'related', 'five', 'men', 'have', 'been', 'arrested', 'none', 'of', 'those', 'hurt', 'are', 'thought', 'to', 'have', 'life', 'threatening', 'injuries', 'image', 'copyright', 'shulem', 'stern', 'image', 'caption', 'one']...
#  - Document 5766: ['the', 'public', 'order', 'and', 'safety', 'special', 'powers', 'act', 'aims', 'to', 'reduce', 'the', 'risk', 'of', 'security', 'operations', 'being', 'compromised', 'by', 'unauthorised', 'communications', 'singapore', 'parliament', 'on', 'wednesday', 'mar', 'approved', 'legislation', 'requiring', 'people', 'in', 'the', 'vicinity', 'of', 'serious', 'incidents', 'such', 'as', 'terrorist', 'attack', 'to', 'stop', 'taking', 'or', 'sharing', 'pictures', 'or', 'videos', 'of', 'the', 'incident', 'area', 'and', 'to', 'stop', 'text', 'or', 'audio', 'messaging', 'about', 'security', 'operations', 'this', 'communications', 'stop', 'order', 'cso', 'aims', 'to', 'minimise', 'terrorists', 'access', 'to', 'information', 'which', 'could', 'compromise', 'law', 'enforcement', 'operations', 'it', 'can', 'only', 'be', 'activated', 'by', 'the', 'commissioner', 'of', 'police', 'cp', 'after', 'the', 'minister', 'for', 'home', 'affairs', 'has', 'activated', 'the']...
#  - Document 1087: ['this', 'story', 'is', 'from', 'march', 'representative', 'image', 'reuters', 'london', 'the', 'british', 'government', 'issued', 'on', 'wednesday', 'new', 'guidelines', 'for', 'handing', 'down', 'sentences', 'in', 'terrorism', 'related', 'cases', 'and', 'introduced', 'longer', 'jail', 'terms', 'for', 'suspects', 'caught', 'in', 'the', 'early', 'stages', 'of', 'plotting', 'terror', 'attack', 'under', 'the', 'terrorism', 'offences', 'definitive', 'guideline', 'published', 'by', 'the', 'sentencing', 'council', 'offenders', 'found', 'guilty', 'of', 'playing', 'even', 'minor', 'role', 'in', 'planning', 'terrorist', 'attack', 'would', 'receive', 'harsher', 'penalties', 'when', 'the', 'new', 'guidelines', 'come', 'into', 'force', 'from', 'april', 'the', 'new', 'guidelines', 'will', 'keep', 'the', 'same', 'maximum', 'sentence', 'of', 'life', 'imprisonment', 'with', 'minimum', 'term', 'of', 'years', 'for', 'terrorism', 'related', 'cases', 'however', 'the']...
#  - Document 6202: ['flights', 'were', 'suspended', 'at', 'gatwick', 'airport', 'following', 'reports', 'of', 'drones', 'flying', 'close', 'to', 'the', 'airfield', 'here', 'we', 'look', 'at', 'the', 'law', 'surrounding', 'drones', 'what', 'are', 'the', 'restrictions', 'around', 'flying', 'drones', 'near', 'airports', 'earlier', 'this', 'year', 'new', 'laws', 'came', 'into', 'force', 'which', 'ban', 'all', 'drones', 'from', 'flying', 'above', 'ft', 'and', 'within', 'km', 'of', 'airport', 'boundaries', 'drone', 'users', 'who', 'flout', 'the', 'height', 'and', 'airport', 'boundary', 'restrictions', 'could', 'face', 'an', 'unlimited', 'fine', 'up', 'to', 'five', 'years', 'in', 'prison', 'or', 'both', 'research', 'funded', 'by', 'the', 'department', 'for', 'transport', 'dft', 'found', 'that', 'drone', 'weighing', 'could', 'smash', 'helicopter', 'windscreen', 'and', 'one', 'weighing', 'kg', 'could', 'critically', 'damage']...
#  - Document 1961: ['urgent', 'fire', 'safety', 'work', 'is', 'to', 'take', 'place', 'on', 'four', 'of', 'the', 'five', 'towers', 'hundreds', 'of', 'residents', 'of', 'four', 'london', 'tower', 'blocks', 'have', 'spent', 'the', 'night', 'in', 'emergency', 'accommodation', 'after', 'they', 'were', 'told', 'to', 'leave', 'their', 'homes', 'amid', 'fire', 'safety', 'fears', 'the', 'blocks', 'in', 'camden', 'north', 'london', 'containing', 'up', 'to', 'households', 'were', 'evacuated', 'late', 'last', 'night', 'following', 'news', 'that', 'similar', 'cladding', 'was', 'used', 'on', 'the', 'chalcots', 'estate', 'to', 'that', 'which', 'spread', 'the', 'grenfell', 'tower', 'fire', 'in', 'kensington', 'earlier', 'this', 'month', 'council', 'leader', 'georgia', 'gould', 'said', 'that', 'following', 'checks', 'insulation', 'was', 'found', 'to', 'be', 'safe', 'but', 'external', 'cladding', 'on', 'the', 'blocks']...
# Query: 'What does the peace accord with FARC mean for Colombia’s future political landscape?'
# Top documents:
#  - Document 562: ['bogota', 'colombian', 'president', 'juan', 'manuel', 'santos', 'said', 'that', 'ceasefire', 'with', 'farc', 'rebels', 'will', 'end', 'on', 'october', 'as', 'both', 'sides', 'scramble', 'to', 'find', 'solution', 'to', 'the', 'half', 'century', 'conflict', 'after', 'voters', 'rejected', 'peace', 'deal', 'the', 'chief', 'of', 'the', 'revolutionary', 'armed', 'forces', 'of', 'colombia', 'farc', 'rodrigo', 'londono', 'better', 'known', 'as', 'timoleon', 'timochenko', 'jimenez', 'promptly', 'took', 'to', 'twitter', 'to', 'ask', 'and', 'after', 'that', 'the', 'war', 'continues', 'just', 'day', 'earlier', 'he', 'had', 'vowed', 'the', 'guerrillas', 'would', 'continue', 'to', 'observe', 'the', 'ceasefire', 'despite', 'the', 'referendum', 'results', 'hope', 'we', 'can', 'move', 'forward', 'to', 'realize', 'the', 'necessary', 'agreement', 'to', 'find', 'solution', 'to', 'this', 'conflict', 'santos', 'said', 'in']...
#  - Document 7214: ['image', 'copyright', 'getty', 'images', 'image', 'caption', 'the', 'first', 'peace', 'deal', 'met', 'resistance', 'as', 'many', 'claimed', 'it', 'allowed', 'farc', 'rebels', 'to', 'get', 'away', 'with', 'murder', 'the', 'colombian', 'government', 'and', 'the', 'farc', 'rebel', 'group', 'have', 'announced', 'new', 'peace', 'agreement', 'six', 'weeks', 'after', 'the', 'original', 'deal', 'was', 'rejected', 'in', 'popular', 'vote', 'the', 'two', 'sides', 'which', 'have', 'been', 'holding', 'talks', 'in', 'cuba', 'for', 'four', 'years', 'said', 'the', 'revised', 'plan', 'incorporated', 'proposals', 'from', 'the', 'opposition', 'and', 'others', 'groups', 'the', 'initial', 'deal', 'had', 'been', 'deemed', 'to', 'be', 'too', 'favourable', 'to', 'the', 'left', 'wing', 'rebels', 'the', 'new', 'agreement', 'is', 'not', 'expected', 'to', 'be', 'put', 'to', 'another', 'popular']...
#  - Document 449: ['bogota', 'colombia', 'referendum', 'defeat', 'for', 'peace', 'deal', 'with', 'leftist', 'rebels', 'leaves', 'colombians', 'with', 'no', 'plan', 'to', 'save', 'an', 'accord', 'that', 'sought', 'to', 'bring', 'an', 'end', 'to', 'half', 'century', 'of', 'hostilities', 'instead', 'of', 'winning', 'by', 'an', 'almost', 'two', 'to', 'one', 'margin', 'sunday', 'as', 'pre', 'election', 'polls', 'had', 'predicted', 'those', 'favoring', 'the', 'accord', 'with', 'the', 'revolutionary', 'armed', 'forces', 'of', 'colombia', 'lost', 'by', 'razor', 'thin', 'margin', 'percent', 'to', 'percent', 'for', 'those', 'against', 'the', 'deal', 'both', 'president', 'juan', 'manuel', 'santos', 'and', 'leaders', 'of', 'the', 'farc', 'after', 'four', 'years', 'of', 'negotiations', 'vowed', 'to', 'push', 'ahead', 'giving', 'no', 'hint', 'they', 'want', 'to', 'resume', 'war', 'that', 'has']...
#  - Document 334: ['bogota', 'reuters', 'colombia', 'president', 'juan', 'manuel', 'santos', 'and', 'marxist', 'farc', 'rebel', 'leader', 'rodrigo', 'londono', 'signed', 'revised', 'peace', 'accord', 'on', 'thursday', 'in', 'far', 'more', 'sober', 'ceremony', 'than', 'first', 'deal', 'rejected', 'last', 'month', 'by', 'millions', 'at', 'plebiscite', 'as', 'they', 'inked', 'the', 'pact', 'with', 'pen', 'made', 'from', 'bullet', 'at', 'historic', 'bogota', 'theater', 'onlookers', 'chanted', 'we', 'did', 'it', 'the', 'new', 'accord', 'to', 'end', 'years', 'of', 'war', 'in', 'latin', 'america', 'fourth', 'largest', 'economy', 'was', 'put', 'together', 'in', 'just', 'over', 'month', 'after', 'the', 'original', 'pact', 'was', 'narrowly', 'and', 'unexpectedly', 'defeated', 'in', 'an', 'oct', 'referendum', 'for', 'being', 'too', 'lenient', 'on', 'the', 'rebels', 'the', 'government', 'and', 'revolutionary', 'armed']...
#  - Document 349: ['bogota', 'reuters', 'colombia', 'president', 'juan', 'manuel', 'santos', 'on', 'thursday', 'extended', 'his', 'ceasefire', 'with', 'marxist', 'farc', 'rebels', 'through', 'the', 'end', 'of', 'the', 'year', 'as', 'he', 'seeks', 'to', 'revive', 'peace', 'accord', 'to', 'end', 'five', 'decades', 'of', 'war', 'after', 'voters', 'rejected', 'the', 'hard', 'fought', 'deal', 'in', 'referendum', 'colombia', 'president', 'juan', 'manuel', 'santos', 'speaks', 'to', 'guests', 'after', 'receiving', 'the', 'clinton', 'global', 'citizen', 'award', 'in', 'new', 'york', 'september', 'reuters', 'eduardo', 'munoz', 'file', 'photo', 'the', 'original', 'ceasefire', 'which', 'was', 'put', 'in', 'place', 'in', 'august', 'was', 'nullified', 'when', 'the', 'peace', 'accord', 'was', 'rejected', 'in', 'plebiscite', 'earlier', 'this', 'month', 'he', 'had', 'already', 'extended', 'it', 'to', 'oct', 'the', 'decision']...

# %% [markdown]
# <h2>PRE-TRAINED GLOVE MODEL</h2>

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.7.1/en_core_web_md-3.7.1-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 38.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /opt/conda/lib/python3.10/site-packages (from en-core-web-md==3.7.1) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.9.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (70.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /opt/conda/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.4)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %% [markdown]
# Doing the same thing but this time with pre-trained GLOVE model. Further, using cosine similarity to find the top 5 relevant documents for each query.

# %%
import spacy

# Load Spacy's pre-trained model with GloVe embeddings
# For example, 'en_core_web_md' includes GloVe embeddings with 300 dimensions
nlp = spacy.load("en_core_web_md")  # Ensure the model is downloaded with `python -m spacy download en_core_web_md`

def load_documents(folder_path):
    """
    Load text files in a given folder.
    
    Args:
        folder_path (str): Path to the folder containing .txt documents.
    
    Returns:
        list of str: List of document contents as strings.
    """
    documents = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
                documents.append(content)
    return documents

def mean_pool_embedding(text):
    """
    Compute the mean-pooling of word embeddings for a given text using Spacy.
    
    Args:
        text (str): Input text to vectorize.
    
    Returns:
        numpy.ndarray: Mean-pooled vector for the input text.
    """
    doc = nlp(text)
    word_vectors = [token.vector for token in doc if token.has_vector]
    
    if not word_vectors:
        return np.zeros(nlp.vocab.vectors_length)  # Return a zero vector if no words have embeddings
    return np.mean(word_vectors, axis=0)

def vectorize_documents(documents):
    """
    Vectorize a list of documents using mean-pooling with Spacy embeddings.
    
    Args:
        documents (list of str): List of document contents as strings.
    
    Returns:
        list of numpy.ndarray: List of mean-pooled document vectors.
    """
    return [mean_pool_embedding(doc) for doc in documents]

def vectorize_queries(queries):
    """
    Vectorize a list of queries using mean-pooling with Spacy embeddings.
    
    Args:
        queries (list of str): List of query strings.
    
    Returns:
        list of numpy.ndarray: List of mean-pooled query vectors.
    """
    return [mean_pool_embedding(query) for query in queries]

def rank_documents(queries, query_vectors, document_vectors, k=5):
    """
    Rank documents for each query based on cosine similarity.
    
    Args:
        queries (list of str): List of query strings.
        query_vectors (list of numpy.ndarray): List of query vectors.
        document_vectors (list of numpy.ndarray): List of document vectors.
        k (int): Number of top documents to retrieve.
    
    Returns:
        dict: A dictionary with queries as keys and lists of top-k document indices as values.
    """
    rankings = {}
    for query, query_vector in zip(queries, query_vectors):
        similarities = cosine_similarity([query_vector], document_vectors)[0]
        ranked_indices = np.argsort(similarities)[::-1][:k]
        rankings[query] = ranked_indices
    return rankings
    

# Load documents
documents = load_documents(folder_path)

# Vectorize documents and queries
document_vectors = vectorize_documents(documents)
query_vectors = vectorize_queries(queries)

# Rank top-k documents for each query
k = 5  # Number of top documents to retrieve for each query
rankings = rank_documents(queries, query_vectors, document_vectors, k)

# Display rankings
for query, indices in rankings.items():
    print(f"Query: '{query}'")
    print("Top documents:")
    for idx in indices:
        print(f" - Document {idx}: {documents[idx][:100]}...")  # Display first 100 chars of each document
# Out:
# Query: 'What impact did the recent bombings in Baghdad have on local security measures?'
# Top documents:
#  - Document 5267: Story highlights Nine police officers and seven residents killed in coordinated attack, police say
#
# ...
#  - Document 7238: Armed bandits stormed a mining site in a remote village late Wednesday shooting at residents, Mohamm...
#  - Document 6382: Bandits have on Wednesday attacked two villages in Anka Local Government Area of Zamfara, killing so...
#  - Document 4982: A suicide attack at a voter registration centre in the Afghan capital Kabul has killed at least 31 p...
#  - Document 3312: With the motives of the Champs-Elysées gunman considered terror-related, the timing just three days ...
# Query: 'How has the Indonesian forest fire crisis affected neighboring countries like Singapore?'
# Top documents:
#  - Document 381: BEIJING (AP) — All 33 coal miners trapped underground in a gas explosion earlier this week have been...
#  - Document 7044: A dust storm that engulfed parts of Australia’s outback has swept through Sydney, sparking public he...
#  - Document 3513: TOKYO: Japanese rescue workers searched the ruins of homes on Thursday looking for dozens of people ...
#  - Document 4699: Over the weekend, wildfires in central Portugal killed at least 63 people and injured 135 others, ma...
#  - Document 2035: Cyclone Debbie: Meet the storm chaser who gets a thrill from severe weather
#
# Paul Lyons has learnt h...
# Query: 'What measures are in place to protect Shia pilgrims in Iraq following recent attacks?'
# Top documents:
#  - Document 1806: A mother and baby who fled from militia violence in Kasai Province in the Democratic Republic of the...
#  - Document 7238: Armed bandits stormed a mining site in a remote village late Wednesday shooting at residents, Mohamm...
#  - Document 423: you've reached a subscriber-only article. Sign up now and access the full breadth of The Daily Star ...
#  - Document 3392: MOSUL, Iraq — The Latest on the Iraqi offensive to retake Mosul (all times local):
#
# Iraqi forces try...
#  - Document 6628: At least 14 people have been killed in South Sudan after new fighting erupted between government for...
# Query: 'How did Alexander Van der Bellen's victory in the Austrian election impact European politics?'
# Top documents:
#  - Document 5578: Image copyright Bart Maat Image caption Mr Van de Steur's resignation puts pressure on the Dutch gov...
#  - Document 750: The European Union is facing fresh turmoil as Italy’s prime minister Matteo Renzi announced his resi...
#  - Document 3854: Image copyright EPA Image caption Despite occasional differences, Mr Kohl forged alliances with UK P...
#  - Document 2332: Image copyright AFP Image caption Italy's Antonio Tajani will be the next head of the European Parli...
#  - Document 2118: (CNN) George H.W. Bush, the 41st President, whose steady hand and foreign policy vision led the nati...
# Query: 'What are the implications of the U.S. Supreme Court’s ruling in Salman v. U.S. for insider trading laws?'
# Top documents:
#  - Document 4353: (CNN) Another federal court has ruled against President Donald Trump's revised executive order limit...
#  - Document 6940: CLOSE
#
# The Supreme Court ruled in a case brought by victims of Middle East terrorism. (Photo: Michae...
#  - Document 7233: WASHINGTON (Reuters) - The U.S. Supreme Court on Monday rebuffed a Republican bid to revive a strict...
#  - Document 405: (Reuters) - The families of some of the 26 children and educators killed at a Connecticut elementary...
#  - Document 4818: Ali Akbar Salehi, the head of Iran’s Atomic Energy Organization, announced on Wednesday that a new f...
# Query: 'What challenges remain after Colombia’s peace accord with FARC was signed?'
# Top documents:
#  - Document 5369: David Davis, Britain's chief negotiator in talks over the country's planned departure from the Europ...
#  - Document 2472: ADDIS ABABA, Ethiopia -- While traveling in Africa, Secretary of State Rex Tillerson struck a cautio...
#  - Document 2524: Taliban: 5 freed from US military prison now in Qatar office
#
# KABUL, Afghanistan (AP) — Five members...
#  - Document 1392: The resignation of two British cabinet ministers are matters for UK Prime Minster Theresa May, a spo...
#  - Document 310: Image copyright Reuters Image caption Grace Mugabe is the second wife of Zimbabwean President Robert...
# Query: 'How are Egyptian authorities responding to the recent killing of a policeman in Cairo?'
# Top documents:
#  - Document 2924: ABUJA (Reuters) - Gunmen killed 11 people and wounded 18 others in a church in southeastern Nigeria ...
#  - Document 6910: The Islamic militant group, which rules Gaza, said Israel “will pay a heavy price” for the explosion...
#  - Document 4139: BAUCHI, Nigeria (Reuters) - Gunmen have killed more than 30 gold miners in a remote area of northern...
#  - Document 4060: BUENOS AIRES (Reuters) - Argentine police have seized a cache of Nazi artefacts hidden behind a libr...
#  - Document 6616: Demonstrators flooded the Ethiopian capital Addis Ababa on Monday, blocking roads and shutting busin...
# Query: 'What are the safety protocols in place at the New York City Metropolitan Opera after a recent disruption?'
# Top documents:
#  - Document 3353: The Civil Aviation Authority is launching an investigation into the plane crash in Northland this af...
#  - Document 1311: Image copyright Presidence Madagascar Image caption Nearly 40 people were injured a stampede at an i...
#  - Document 4887: At least one person has died following a fire at the Perseus shopping centre in the west of Moscow.
# ...
#  - Document 7072: A second soldier has died following an incident at a military firing range in Pembrokeshire.
#
# Defenc...
#  - Document 5903: Source: Xinhua| 2018-08-25 21:01:18|Editor: Chengcheng
#
# Video Player Close
#
# HARBIN, Aug. 25 (Xinhua)...
# Query: 'What are the prospects for diplomatic relations between Iran and Canada following the release of Homa Hoodfar?'
# Top documents:
#  - Document 1807: Baku. 29 November. REPORT.AZ/ Azerbaijan and South Africa are ready to sign 7 memorandums, which wil...
#  - Document 3068: TBILISI (Reuters) - Georgia said on Tuesday it had started procedures to sever diplomatic relations ...
#  - Document 4819: The White House released a joint statement from President Trump and North Korea’s Kim Jong Un after ...
#  - Document 6389: Tajikistan Foreign Minister Aslov Sirodjidin Muhridinovich said the visit of Md Shahriar Alam would ...
#  - Document 5111: The move comes six months after Invenergy formally notified the Polish government of its intention t...
# Query: 'What were the key issues in The Gambia’s recent elections?'
# Top documents:
#  - Document 3599: The Pulitzer Prizes on Monday honored The Washington Post for hard-hitting reporting on Donald Trump...
#  - Document 2748:
# • Sean Hannity was revealed to be the mysterious third client of Donald Trump’s lawyer Michael Cohe...
#  - Document 3548: The Maldives has left the Commonwealth, claiming it was "unfairly and unjustly" treated by the globa...
#  - Document 4976: More reporters are behind bars than ever before.
#
# The Committee to Protect Journalists said 259 jour...
#  - Document 1209: The Latest: Canada raises detention of citizen with China
#
# TORONTO (AP) — The Latest on the detentio...
# Query: 'How is Singapore addressing the health and environmental impacts of Indonesian fires?'
# Top documents:
#  - Document 4022: More than 1 million people died from dirty air in one year, according to World Health Organisation
#
# ...
#  - Document 1769: Lions used to roam across most of Africa, southern Europe, and the Middle East, all the way to north...
#  - Document 2095: Image copyright SPL
#
# The amount of plastic in the ocean is set to triple in a decade unless litter i...
#  - Document 1598: Image copyright ZSL Image caption Protected parks and reserves for cheetahs are not sufficient as th...
#  - Document 5087: Abuja — FLOODS devastating Nigeria have left at least 15 people dead and over 25 000 people affected...
# Query: 'What security precautions are being taken for future religious gatherings in Iraq after recent attacks?'
# Top documents:
#  - Document 4285: Image copyright Getty Images Image caption The social media crackdown is being seen as an extension ...
#  - Document 5349: Bangladesh Prime Minister Sheikh Hasina on Tuesday accused Buddhist-majority Myanmar of committing “...
#  - Document 5098: Mujahid Safodien, AFP | File photo of South African security officials and migrants in Johannesburg ...
#  - Document 2041: DHAKA, Bangladesh (AFP) — Bangladeshi Prime Minister Sheikh Hasina headed for the United Nations Gen...
#  - Document 5150: YANGON (Reuters) - Eight people died and 36 were arrested in clashes between the Myanmar army and wh...
# Query: 'How does the Austrian election reflect broader political trends in Europe?'
# Top documents:
#  - Document 5973: Pro-EU campaigners will hold a national day of action on Saturday. (David Mirzoeff/PA)
#
# Thousands of...
#  - Document 7494: Erstmals hat mit Großbritannien ein EU-Mitglied den Austritt aus dem Staatenbund offiziell beantragt...
#  - Document 4224: STOCKHOLM – Sweden woke Monday to the prospect of weeks of political uncertainty after the country’s...
#  - Document 5696: (Daniel Rihs / 13 Photo)
#
# At 45, Alain Berset is the youngest politician to become Swiss president s...
#  - Document 724: Germany's lower house of parliament, the Bundestag, on Thursday approved a draft law that would prev...
# Query: 'What steps are being taken to prevent further incidents like the Metropolitan Opera disruption?'
# Top documents:
#  - Document 3175: Two held on Friday night, police say, as airport bosses expect to run full schedule on Saturday
#
# Thi...
#  - Document 6202: Flights were suspended at Gatwick Airport following reports of drones flying close to the airfield. ...
#  - Document 3179: Media playback is unsupported on your device Media caption The Met said drivers aim to end pursuits ...
#  - Document 7164: Image copyright Roxane Wephre Image caption Police are not treating the crash as being terrorist-rel...
#  - Document 4394: Media Sound Holdings Privacy Statement 1. Who are we? We are Media Sound Holdings (MSH). Media Sound...
# Query: 'What does the peace accord with FARC mean for Colombia’s future political landscape?'
# Top documents:
#  - Document 11: This move comes just months after long-time President Abdel-Aziz Bouteflika resigned from office fol...
#  - Document 6599: Image copyright Human Rights Centre Somaliland Image caption Poet Nacima Qorane was found guilty of ...
#  - Document 442: Here's what Secretary of State Rex Tillerson, aka the nation's top diplomat, had to say about the la...
#  - Document 2334: These have been trying and soul-searching times for Facebook CEO Mark Zuckerberg. While his global a...
#  - Document 151: LONDON — Theresa May just confirmed that Britain will be leaving the single market as part of its wi...

# %% [markdown]
# <h2>DPR model</h2>

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.45.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)

# %%
import torch
from transformers import DPRContextEncoder, DPRQuestionEncoder, DPRContextEncoderTokenizer, DPRQuestionEncoderTokenizer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Set up the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load DPR encoders and tokenizers, and move models to GPU if available
question_encoder = DPRQuestionEncoder.from_pretrained("facebook/dpr-question_encoder-single-nq-base").to(device)
question_tokenizer = DPRQuestionEncoderTokenizer.from_pretrained("facebook/dpr-question_encoder-single-nq-base")
context_encoder = DPRContextEncoder.from_pretrained("facebook/dpr-ctx_encoder-single-nq-base").to(device)
context_tokenizer = DPRContextEncoderTokenizer.from_pretrained("facebook/dpr-ctx_encoder-single-nq-base")

def encode_queries(queries):
    """
    Encode a list of queries using the DPR question encoder with truncation.
    
    Args:
        queries (list of str): List of query strings.
    
    Returns:
        numpy.ndarray: Encoded query vectors.
    """
    query_embeddings = []
    for query in queries:
        # Tokenize and encode each query individually with truncation
        inputs = question_tokenizer(query, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)
        with torch.no_grad():
            embedding = question_encoder(**inputs).pooler_output
            query_embeddings.append(embedding.cpu().numpy())  # Move back to CPU for aggregation
    
    # Stack embeddings to form a 2D array for all query vectors
    return np.vstack(query_embeddings)

def encode_documents(documents):
    """
    Encode a list of documents using the DPR context encoder with truncation.
    
    Args:
        documents (list of str): List of document contents as strings.
    
    Returns:
        numpy.ndarray: Encoded document vectors.
    """
    document_embeddings = []
    for doc in documents:
        # Tokenize and encode each document individually with truncation
        inputs = context_tokenizer(doc, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)
        with torch.no_grad():
            embedding = context_encoder(**inputs).pooler_output
            document_embeddings.append(embedding.cpu().numpy())  # Move back to CPU for aggregation
    
    # Stack embeddings to form a 2D array for all document vectors
    return np.vstack(document_embeddings)

def rank_documents(queries, query_vectors, document_vectors, k=5):
    """
    Rank documents for each query based on cosine similarity.
    
    Args:
        queries (list of str): List of query strings.
        query_vectors (numpy.ndarray): Array of query vectors.
        document_vectors (numpy.ndarray): Array of document vectors.
        k (int): Number of top documents to retrieve.
    
    Returns:
        dict: A dictionary with queries as keys and lists of top-k document indices as values.
    """
    rankings = {}
    for i, query_vector in enumerate(query_vectors):
        similarities = cosine_similarity([query_vector], document_vectors)[0]
        ranked_indices = np.argsort(similarities)[::-1][:k]
        rankings[queries[i]] = ranked_indices
    return rankings


# Encode documents and queries
document_vectors = encode_documents(documents)
query_vectors = encode_queries(queries)

# Rank top-k documents for each query
k = 5  # Number of top documents to retrieve for each query
rankings = rank_documents(queries, query_vectors, document_vectors, k)

# Display rankings
for query, indices in rankings.items():
    print(f"Query: '{query}'")
    print("Top documents:")
    for idx in indices:
        print(f" - Document {idx}: {documents[idx][:100]}...")  # Display first 100 chars of each document
# Out:
# Some weights of the model checkpoint at facebook/dpr-question_encoder-single-nq-base were not used when initializing DPRQuestionEncoder: ['question_encoder.bert_model.pooler.dense.bias', 'question_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing DPRQuestionEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRQuestionEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at facebook/dpr-ctx_encoder-single-nq-base were not used when initializing DPRContextEncoder: ['ctx_encoder.bert_model.pooler.dense.bias', 'ctx_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing DPRContextEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRContextEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'DPRQuestionEncoderTokenizer'.
# The class this function is called from is 'DPRContextEncoderTokenizer'.
# Query: 'What impact did the recent bombings in Baghdad have on local security measures?'
# Top documents:
#  - Document 1287: Widespread unrest is engulfing southern Iraq as Iraqis frustrated by shortages of electricity, water...
#  - Document 5530: Abbo Hyder, AFP | This picture taken on October 24, 2018 shows fire near the wreckage of a car repor...
#  - Document 6397: Protests that began last week in Iraq are continuing amid widespread anger over abysmal public servi...
#  - Document 1800: The coordinated attack is another stinging blow to NATO-backed Afghan forces.
#
# KANDAHAR, Afghanistan...
#  - Document 330: BAGHDAD (AP) — A car bomb exploded outside a popular ice cream shop in central Baghdad just after mi...
# Query: 'How has the Indonesian forest fire crisis affected neighboring countries like Singapore?'
# Top documents:
#  - Document 3937: Six Indonesian provinces have declared states of emergency as forest fires blanketed a swath of Sout...
#  - Document 361: JAKARTA, Indonesia (AP) -- A volatile volcano in northern Indonesia erupted Sunday, spewing smoke an...
#  - Document 3473: The outbreak and the warnings come as a potential blow to tourism in one of the world's busiest trav...
#  - Document 1973: Flooding following heavy rain has killed 60 people and left over 44,000 homeless in North Korea, the...
#  - Document 1044: Scores were left dead and hundreds more injured in Indonesia early Sunday as a tsunami hit the islan...
# Query: 'What measures are in place to protect Shia pilgrims in Iraq following recent attacks?'
# Top documents:
#  - Document 7201: A second lethal blow was struck Thursday at the controversial travel ban imposed by President Donald...
#  - Document 5101: The ceasefire will last six months and could be "automatically extended" for another six months, Ale...
#  - Document 142: A 72-hour ceasefire in Yemen is due to begin on Wednesday night, the UN envoy for Yemen said on Mond...
#  - Document 6708: The Iran-allied Houthis, who are battling the internationally recognized government of Yemen's Presi...
#  - Document 3690: The United Nations has delayed the vote on the East Ghouta ceasefire resolution until 5pm GMT on Sat...
# Query: 'How did Alexander Van der Bellen's victory in the Austrian election impact European politics?'
# Top documents:
#  - Document 1121: VIENNA (Reuters) - Iran has remained within key limits on its nuclear activities imposed by its 2015...
#  - Document 3119: Millions of people across the UK are set to vote in the general election on Thursday where the rulin...
#  - Document 6793: Vocal Donald Trump critic says he wants Germany to be an ‘anchor of hope’ after he was voted in by p...
#  - Document 2929: Uncertainty over President Trump’s trip to the elite Swiss Alps gathering - attended by royals, gove...
#  - Document 3445: It has been a bleak winter for Europe’s long-suffering left. In the span of less than two months, Fr...
# Query: 'What are the implications of the U.S. Supreme Court’s ruling in Salman v. U.S. for insider trading laws?'
# Top documents:
#  - Document 7201: A second lethal blow was struck Thursday at the controversial travel ban imposed by President Donald...
#  - Document 2820: WASHINGTON (Reuters) - The Obama administration, in its latest bid to prevent American companies fro...
#  - Document 5951: WASHINGTON (Reuters) - The U.S. Supreme Court on Monday struck down a gender distinction in U.S. imm...
#  - Document 6134: The ruling was 5-4 along partisan lines, with Chief Justice John Roberts writing for the conservativ...
#  - Document 616: NEW YORK (AP) — Google, Apple and other tech giants expressed dismay over an executive order on immi...
# Query: 'What challenges remain after Colombia’s peace accord with FARC was signed?'
# Top documents:
#  - Document 24: Colombia's leftist FARC rebel force formally completed its disarmament process on Monday to end half...
#  - Document 1474: Colombia’s military and ELN rebels resumed hostilities on Wednesday after failing to agree to an ext...
#  - Document 334: BOGOTA (Reuters) - Colombia’s President Juan Manuel Santos and Marxist FARC rebel leader Rodrigo Lon...
#  - Document 6562: Venzuelan President Nicolas Maduro says the government's Denfense Council met Monday to discuss the ...
#  - Document 562: BOGOTA: Colombian President Juan Manuel Santos said that a ceasefire with FARC rebels will end on Oc...
# Query: 'How are Egyptian authorities responding to the recent killing of a policeman in Cairo?'
# Top documents:
#  - Document 490: The attacks in the Nile Delta cities of Tanta and Alexandria followed a Cairo church bombing in Dece...
#  - Document 4472: CAIRO (Reuters) - Egypt’s parliament on Wednesday backed plans to hand over two uninhabited Red Sea ...
#  - Document 7268: CAIRO (Reuters) - An Egyptian court rejected on Monday a government plan to transfer two uninhabited...
#  - Document 5856: CAIRO, May 11, 2018 (WAFA) – Egyptian authorities decided on Friday to open the Rafah border crossin...
#  - Document 6490: CAIRO (Reuters) - Egyptian authorities pressed for a high turnout on Tuesday on the second day of a ...
# Query: 'What are the safety protocols in place at the New York City Metropolitan Opera after a recent disruption?'
# Top documents:
#  - Document 4184: NEW YORK -- Saturday’s performance of “Guillame Tell” at the Metropolitan Opera House was disrupted ...
#  - Document 1938: Two people have been killed and more than 200 were injured after two earthquakes struck Taiwan.
#
# The...
#  - Document 2119: Elon Musk has said he has received permission to build an underground east coast "hyperloop" that wi...
#  - Document 4080: A look at scenarios and options DACA recipients have as the DACA program phases out in the next two ...
#  - Document 2462: An explosion has injured 25, four seriously, and destroyed a building in the German city of Wupperta...
# Query: 'What are the prospects for diplomatic relations between Iran and Canada following the release of Homa Hoodfar?'
# Top documents:
#  - Document 4267: A ship unloads a cargo of wheat at the Red Sea port of Hodeida, Yemen, April 1. The port, controlled...
#  - Document 6892: Suspected 9/11 recruiter Mohammed Haydar Zammar captured in Syria
#
# The 9/11 Commission Report brande...
#  - Document 6504: DUBAI (Reuters) - Iran said on Monday it had freed a Canadian-Iranian academic detained since June, ...
#  - Document 742: Gain a global perspective on the US and go beyond with curated news and analysis from 600 journalist...
#  - Document 5741: Road to N. Korea's denuclearization is littered with failure
#
# SEOUL, South Korea (AP) — Bill Clinton...
# Query: 'What were the key issues in The Gambia’s recent elections?'
# Top documents:
#  - Document 4401: Voters in The Gambia are casting their ballots in the first election since the departure of long-tim...
#  - Document 6114: Gambia has no natural resources to speak of, and around half its population is living in poverty. Bu...
#  - Document 110: DAKAR, Senegal -- Gambia's ruler of more than 22 years announced late Friday that he no longer accep...
#  - Document 302: The Gambia’s new government has accused supporters of the former president, Yahya Jammeh, of welcomi...
#  - Document 7008: Gambian president Yahya Jammeh has so far been unmoved by calls from fellow African leaders, the Uni...
# Query: 'How is Singapore addressing the health and environmental impacts of Indonesian fires?'
# Top documents:
#  - Document 3937: Six Indonesian provinces have declared states of emergency as forest fires blanketed a swath of Sout...
#  - Document 361: JAKARTA, Indonesia (AP) -- A volatile volcano in northern Indonesia erupted Sunday, spewing smoke an...
#  - Document 3473: The outbreak and the warnings come as a potential blow to tourism in one of the world's busiest trav...
#  - Document 4465: PANDEGLANG (Indonesia), Dec 23 — A tsunami killed at least 222 people and injured hundreds on the In...
#  - Document 1044: Scores were left dead and hundreds more injured in Indonesia early Sunday as a tsunami hit the islan...
# Query: 'What security precautions are being taken for future religious gatherings in Iraq after recent attacks?'
# Top documents:
#  - Document 7201: A second lethal blow was struck Thursday at the controversial travel ban imposed by President Donald...
#  - Document 5101: The ceasefire will last six months and could be "automatically extended" for another six months, Ale...
#  - Document 3976: A high-profile group of Jewish leaders cancelled a gala event with Prime Minister Benjamin Netanyahu...
#  - Document 3690: The United Nations has delayed the vote on the East Ghouta ceasefire resolution until 5pm GMT on Sat...
#  - Document 4328: One of the world's most important religious sites and Judaism’s holiest site, Jerusalem’s Temple Mou...
# Query: 'How does the Austrian election reflect broader political trends in Europe?'
# Top documents:
#  - Document 3119: Millions of people across the UK are set to vote in the general election on Thursday where the rulin...
#  - Document 2204: As Austria prepares to take over the European Union presidency on July 1 in the midst of a continent...
#  - Document 3929: PRAGUE (Reuters) - Russia-friendly Czech President Milos Zeman won the first round of voting to reta...
#  - Document 1121: VIENNA (Reuters) - Iran has remained within key limits on its nuclear activities imposed by its 2015...
#  - Document 1126: Image copyright Reuters Image caption Sebastian Kurz has previously vowed to shut down migrant route...
# Query: 'What steps are being taken to prevent further incidents like the Metropolitan Opera disruption?'
# Top documents:
#  - Document 1938: Two people have been killed and more than 200 were injured after two earthquakes struck Taiwan.
#
# The...
#  - Document 2462: An explosion has injured 25, four seriously, and destroyed a building in the German city of Wupperta...
#  - Document 1435: Police in Japan are investigating whether a serial poisoner is responsible for killing as many as 48...
#  - Document 2119: Elon Musk has said he has received permission to build an underground east coast "hyperloop" that wi...
#  - Document 661: Fifteen states and the District of Columbia filed a lawsuit here Wednesday challenging President Tru...
# Query: 'What does the peace accord with FARC mean for Colombia’s future political landscape?'
# Top documents:
#  - Document 24: Colombia's leftist FARC rebel force formally completed its disarmament process on Monday to end half...
#  - Document 334: BOGOTA (Reuters) - Colombia’s President Juan Manuel Santos and Marxist FARC rebel leader Rodrigo Lon...
#  - Document 449: BOGOTA, Colombia — A referendum defeat for a peace deal with leftist rebels leaves Colombians with n...
#  - Document 6562: Venzuelan President Nicolas Maduro says the government's Denfense Council met Monday to discuss the ...
#  - Document 562: BOGOTA: Colombian President Juan Manuel Santos said that a ceasefire with FARC rebels will end on Oc...
